# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib
matplotlib.use('TkAgg')
#%matplotlib inline
import BPV
import pattern_manipulation as pm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import rcParams
import pickle
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import math

matplotlib.style.use('ggplot')
rcParams['text.latex.unicode'] = True
rcParams['text.usetex'] = True
rcParams['text.latex.preamble'] = r'\usepackage{amsthm}', r'\usepackage{amsmath}', r'\usepackage{amssymb}', \
                                   r'\usepackage{amsfonts}'
#rcParams['text.latex.preamble']
#rcParams['text.latex.preamble'] = r'\usepackage{amsthm}'

Wmin = 0.001
Wmax = 0.25
Wnsteps = 30
Wstep = (Wmax - Wmin)/Wnsteps
Wrange = np.arange(Wmin,Wmax,Wstep)

Nmin = 10
Nmax = 150
Nnsteps = 30
Nstep = (Nmax - Nmin)/Nnsteps
Nrange = np.arange(Nmin,Nmax,Nstep, dtype='int')

nproblems = Wnsteps*Nnsteps

data = BPV.Data()
data.read_csv("pixel.dist.csv",False)
data.df.sort_index(by="p",inplace=True,ascending=True)
data.df.set_index(pd.Index([j for j in range(len(data.df))]), inplace=True)
data.df['plog1onp'].sum()
#data.df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2.7770733382327477

# %%
#CALCULATE EXACT SOLUTIONS

entropies = np.zeros((Wnsteps, Nnsteps))
rates = np.zeros((Wnsteps, Nnsteps))
cardinalities = np.zeros((Wnsteps, Nnsteps), dtype='int')
times = np.zeros((Wnsteps, Nnsteps))
indexes = {}

it = 1
for i,j in [(x,y) for x in range(Wnsteps) for y in range(Nnsteps)]:
    W = Wrange[i]
    N = Nrange[j]
    print("\n\nSolving problem {0} out of {1}, for W = {2} and N = {3} i = {4}  j = {5}".format(it, nproblems, W, N,i,j))
    
    prbl_exact = BPV.BPV("pulp",data,N,W,time_solver=True)
    prbl_exact.solve()
    prbl_exact.pprint_solution()
    
    entropies[i,j] = prbl_exact.solution_entropy
    rates[i,j] = prbl_exact.solution_rate
    cardinalities[i,j] = prbl_exact.solution_cardinality
    indexes[(i,j)] = prbl_exact.solution.index
    times[(i,j)] = prbl_exact.solution_time
    it += 1
# Out:
# Solving problem 1 out of 900, for W = 0.001 and N = 10 i = 0  j = 0
#
# Solver =  pulp
# Entropy =  0.009205268286161758
# Cardinality =  10
# Rate =  0.000999587942383
# Solution time in seconds =  0.2984579679905437
#
#
# Solving problem 2 out of 900, for W = 0.001 and N = 14 i = 0  j = 1
#
# Solver =  pulp
# Entropy =  0.009544595144003878
# Cardinality =  14
# Rate =  0.000999780684813
# Solution time in seconds =  0.1441087529528886
#
#
# Solving problem 3 out of 900, for W = 0.001 and N = 18 i = 0  j = 2
#
# Solver =  pulp
# Entropy =  0.009795761647560967
# Cardinality =  18
# Rate =  0.000999832082795
# Solution time in seconds =  0.18421532900538296
#
#
# Solving problem 4 out of 900, for W = 0.001 and N = 22 i = 0  j = 3
#
# Solver =  pulp
# Entropy =  0.009997790434198123
# Cardinality =  22
# Rate =  0.000999973427244
# Solution time in seconds =  0.17940019903471693
#
#
# Solving problem 5 out of 900, for W = 0.001 and N = 26 i = 0  j = 4
#
# Solver =  pulp
# Entropy =  0.010155307299972351
# Cardinality =  26
# Rate =  0.000999690738346
# Solution time in seconds =  0.27965560503071174
#
#
# Solving problem 6 out of 900, for W = 0.001 and N = 30 i = 0  j = 5
#
# Solver =  pulp
# Entropy =  0.010296200433427627
# Cardinality =  30
# Rate =  0.000999947728253
# Solution time in seconds =  0.14484194497345015
#
#
# Solving problem 7 out of 900, for W = 0.001 and N = 34 i = 0  j = 6
#
# Solver =  pulp
# Entropy =  0.010425382585409237
# Cardinality =  34
# Rate =  0.000999665039355
# Solution time in seconds =  0.19902668800204992
#
#
# Solving problem 8 out of 900, for W = 0.001 and N = 38 i = 0  j = 7
#
# Solver =  pulp
# Entropy =  0.010540373367727165
# Cardinality =  38
# Rate =  0.00100005052422
# Solution time in seconds =  0.17123234196333215
#
#
# Solving problem 9 out of 900, for W = 0.001 and N = 42 i = 0  j = 8
#
# Solver =  pulp
# Entropy =  0.010626993124695623
# Cardinality =  42
# Rate =  0.00099912536055
# Solution time in seconds =  0.13645569601794705
#
#
# Solving problem 10 out of 900, for W = 0.001 and N = 46 i = 0  j = 9
#
# Solver =  pulp
# Entropy =  0.01072273946125494
# Cardinality =  46
# Rate =  0.00100001197573
# Solution time in seconds =  0.16303438501199707
#
#
# Solving problem 11 out of 900, for W = 0.001 and N = 50 i = 0  j = 10
#
# Solver =  pulp
# Entropy =  0.010802706970030194
# Cardinality =  50
# Rate =  0.00100007622321
# Solution time in seconds =  0.13594837003620341
#
#
# Solving problem 12 out of 900, for W = 0.001 and N = 54 i = 0  j = 11
#
# Solver =  pulp
# Entropy =  0.010869344921303705
# Cardinality =  54
# Rate =  0.000999356651467
# Solution time in seconds =  0.1482769440044649
#
#
# Solving problem 13 out of 900, for W = 0.001 and N = 58 i = 0  j = 12
#
# Solver =  pulp
# Entropy =  0.010946320429748932
# Cardinality =  58
# Rate =  0.000999986276739
# Solution time in seconds =  0.15935584995895624
#
#
# Solving problem 14 out of 900, for W = 0.001 and N = 62 i = 0  j = 13
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.18847368500428274
#
#
# Solving problem 15 out of 900, for W = 0.001 and N = 66 i = 0  j = 14
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.193939036980737
#
#
# Solving problem 16 out of 900, for W = 0.001 and N = 70 i = 0  j = 15
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.19392332300776616
#
#
# Solving problem 17 out of 900, for W = 0.001 and N = 74 i = 0  j = 16
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.19329098099842668
#
#
# Solving problem 18 out of 900, for W = 0.001 and N = 78 i = 0  j = 17
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.19078940904000774
#
#
# Solving problem 19 out of 900, for W = 0.001 and N = 82 i = 0  j = 18
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.19021517498185858
#
#
# Solving problem 20 out of 900, for W = 0.001 and N = 86 i = 0  j = 19
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.18847249797545373
#
#
# Solving problem 21 out of 900, for W = 0.001 and N = 90 i = 0  j = 20
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.18634751002537087
#
#
# Solving problem 22 out of 900, for W = 0.001 and N = 94 i = 0  j = 21
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.18622738303383812
#
#
# Solving problem 23 out of 900, for W = 0.001 and N = 98 i = 0  j = 22
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.18776807899121195
#
#
# Solving problem 24 out of 900, for W = 0.001 and N = 102 i = 0  j = 23
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.18858675804222003
#
#
# Solving problem 25 out of 900, for W = 0.001 and N = 106 i = 0  j = 24
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.19091554201440886
#
#
# Solving problem 26 out of 900, for W = 0.001 and N = 110 i = 0  j = 25
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.20689262001542374
#
#
# Solving problem 27 out of 900, for W = 0.001 and N = 114 i = 0  j = 26
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.20329698600107804
#
#
# Solving problem 28 out of 900, for W = 0.001 and N = 118 i = 0  j = 27
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.2064049190375954
#
#
# Solving problem 29 out of 900, for W = 0.001 and N = 122 i = 0  j = 28
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.1899589980021119
#
#
# Solving problem 30 out of 900, for W = 0.001 and N = 126 i = 0  j = 29
#
# Solver =  pulp
# Entropy =  0.011000300995338797
# Cardinality =  62
# Rate =  0.000999922029262
# Solution time in seconds =  0.2081834939890541
#
#
# Solving problem 31 out of 900, for W = 0.0093 and N = 10 i = 1  j = 0
#
# Solver =  pulp
# Entropy =  0.0
# Cardinality =  0
# Rate =  0
# Solution time in seconds =  0.19749639701331034
#
#
# Solving problem 32 out of 900, for W = 0.0093 and N = 14 i = 1  j = 1
#
# Solver =  pulp
# Entropy =  0.06771174013886713
# Cardinality =  14
# Rate =  0.00929899989294
# Solution time in seconds =  0.1750205279677175
#
#
# Solving problem 33 out of 900, for W = 0.0093 and N = 18 i = 1  j = 2
#
# Solver =  pulp
# Entropy =  0.07004046025993638
# Cardinality =  18
# Rate =  0.00929995075559
# Solution time in seconds =  0.23769195104250684
#
#
# Solving problem 34 out of 900, for W = 0.0093 and N = 22 i = 1  j = 3
#
# Solver =  pulp
# Entropy =  0.07216256012958025
# Cardinality =  22
# Rate =  0.00929894849496
# Solution time in seconds =  0.20096813200507313
#
#
# Solving problem 35 out of 900, for W = 0.0093 and N = 26 i = 1  j = 4
#
# Solver =  pulp
# Entropy =  0.07371731451147812
# Cardinality =  26
# Rate =  0.00929901274243
# Solution time in seconds =  0.2489652259973809
#
#
# Solving problem 36 out of 900, for W = 0.0093 and N = 30 i = 1  j = 5
#
# Solver =  pulp
# Entropy =  0.07499835204209215
# Cardinality =  30
# Rate =  0.00929969376569
# Solution time in seconds =  0.2202429010067135
#
#
# Solving problem 37 out of 900, for W = 0.0093 and N = 34 i = 1  j = 6
#
# Solver =  pulp
# Entropy =  0.07612989216806995
# Cardinality =  34
# Rate =  0.0092999250566
# Solution time in seconds =  0.16808739403495565
#
#
# Solving problem 38 out of 900, for W = 0.0093 and N = 38 i = 1  j = 7
#
# Solver =  pulp
# Entropy =  0.0771943699997612
# Cardinality =  38
# Rate =  0.00929984795963
# Solution time in seconds =  0.1921171590220183
#
#
# Solving problem 39 out of 900, for W = 0.0093 and N = 42 i = 1  j = 8
#
# Solver =  pulp
# Entropy =  0.07818121237280011
# Cardinality =  42
# Rate =  0.00929867865555
# Solution time in seconds =  0.2710352479480207
#
#
# Solving problem 40 out of 900, for W = 0.0093 and N = 46 i = 1  j = 9
#
# Solver =  pulp
# Entropy =  0.07906850131352611
# Cardinality =  46
# Rate =  0.0092993725283
# Solution time in seconds =  0.1927645179675892
#
#
# Solving problem 41 out of 900, for W = 0.0093 and N = 50 i = 1  j = 10
#
# Solver =  pulp
# Entropy =  0.07985493188416476
# Cardinality =  50
# Rate =  0.0092993853778
# Solution time in seconds =  0.20440864795818925
#
#
# Solving problem 42 out of 900, for W = 0.0093 and N = 54 i = 1  j = 11
#
# Solver =  pulp
# Entropy =  0.08055809100394958
# Cardinality =  54
# Rate =  0.00930000215358
# Solution time in seconds =  0.2614630250027403
#
#
# Solving problem 43 out of 900, for W = 0.0093 and N = 58 i = 1  j = 12
#
# Solver =  pulp
# Entropy =  0.08122114164673175
# Cardinality =  58
# Rate =  0.00929921833436
# Solution time in seconds =  0.1661533520091325
#
#
# Solving problem 44 out of 900, for W = 0.0093 and N = 62 i = 1  j = 13
#
# Solver =  pulp
# Entropy =  0.08184014049079763
# Cardinality =  62
# Rate =  0.00929906414041
# Solution time in seconds =  0.19527488795574754
#
#
# Solving problem 45 out of 900, for W = 0.0093 and N = 66 i = 1  j = 14
#
# Solver =  pulp
# Entropy =  0.08242476088800571
# Cardinality =  66
# Rate =  0.00930009210004
# Solution time in seconds =  0.16206310398411006
#
#
# Solving problem 46 out of 900, for W = 0.0093 and N = 70 i = 1  j = 15
#
# Solver =  pulp
# Entropy =  0.0829575355012426
# Cardinality =  70
# Rate =  0.00929902559193
# Solution time in seconds =  0.21724021900445223
#
#
# Solving problem 47 out of 900, for W = 0.0093 and N = 74 i = 1  j = 16
#
# Solver =  pulp
# Entropy =  0.08347623412588714
# Cardinality =  74
# Rate =  0.00929951387275
# Solution time in seconds =  0.15721004997612908
#
#
# Solving problem 48 out of 900, for W = 0.0093 and N = 78 i = 1  j = 17
#
# Solver =  pulp
# Entropy =  0.08394125797026654
# Cardinality =  78
# Rate =  0.00929906414041
# Solution time in seconds =  0.1616138849640265
#
#
# Solving problem 49 out of 900, for W = 0.0093 and N = 82 i = 1  j = 18
#
# Solver =  pulp
# Entropy =  0.08437529801861036
# Cardinality =  82
# Rate =  0.00929980941115
# Solution time in seconds =  0.14881849201628938
#
#
# Solving problem 50 out of 900, for W = 0.0093 and N = 86 i = 1  j = 19
#
# Solver =  pulp
# Entropy =  0.08479286536495041
# Cardinality =  86
# Rate =  0.00929995075559
# Solution time in seconds =  0.15204229101072997
#
#
# Solving problem 51 out of 900, for W = 0.0093 and N = 90 i = 1  j = 20
#
# Solver =  pulp
# Entropy =  0.08517551317758768
# Cardinality =  90
# Rate =  0.00929903844142
# Solution time in seconds =  0.18101164401741698
#
#
# Solving problem 52 out of 900, for W = 0.0093 and N = 94 i = 1  j = 21
#
# Solver =  pulp
# Entropy =  0.0855570144128763
# Cardinality =  94
# Rate =  0.00929991220711
# Solution time in seconds =  0.15456174197606742
#
#
# Solving problem 53 out of 900, for W = 0.0093 and N = 98 i = 1  j = 22
#
# Solver =  pulp
# Entropy =  0.08592090732866339
# Cardinality =  98
# Rate =  0.00929986080913
# Solution time in seconds =  0.18507954297820106
#
#
# Solving problem 54 out of 900, for W = 0.0093 and N = 102 i = 1  j = 23
#
# Solver =  pulp
# Entropy =  0.08627995568299525
# Cardinality =  102
# Rate =  0.00930000215358
# Solution time in seconds =  0.16428642795654014
#
#
# Solving problem 55 out of 900, for W = 0.0093 and N = 106 i = 1  j = 24
#
# Solver =  pulp
# Entropy =  0.08661935537394014
# Cardinality =  106
# Rate =  0.00929974516367
# Solution time in seconds =  0.1704561979859136
#
#
# Solving problem 56 out of 900, for W = 0.0093 and N = 110 i = 1  j = 25
#
# Solver =  pulp
# Entropy =  0.0869541341065736
# Cardinality =  110
# Rate =  0.00929970661518
# Solution time in seconds =  0.20289148797746748
#
#
# Solving problem 57 out of 900, for W = 0.0093 and N = 114 i = 1  j = 26
#
# Solver =  pulp
# Entropy =  0.08727945232331699
# Cardinality =  114
# Rate =  0.00930000215358
# Solution time in seconds =  0.21377267397474498
#
#
# Solving problem 58 out of 900, for W = 0.0093 and N = 118 i = 1  j = 27
#
# Solver =  pulp
# Entropy =  0.0875939440594959
# Cardinality =  118
# Rate =  0.00929984795963
# Solution time in seconds =  0.22927336499560624
#
#
# Solving problem 59 out of 900, for W = 0.0093 and N = 122 i = 1  j = 28
#
# Solver =  pulp
# Entropy =  0.08789708001214419
# Cardinality =  122
# Rate =  0.00930004070206
# Solution time in seconds =  0.19164726795861498
#
#
# Solving problem 60 out of 900, for W = 0.0093 and N = 126 i = 1  j = 29
#
# Solver =  pulp
# Entropy =  0.08818673970853129
# Cardinality =  126
# Rate =  0.00929960381922
# Solution time in seconds =  0.15361567301442847
#
#
# Solving problem 61 out of 900, for W = 0.017599999999999998 and N = 10 i = 2  j = 0
#
# Solver =  pulp
# Entropy =  0.11154551706778018
# Cardinality =  10
# Rate =  0.0175989258233
# Solution time in seconds =  0.16498365200823173
#
#
# Solving problem 62 out of 900, for W = 0.017599999999999998 and N = 14 i = 2  j = 1
#
# Solver =  pulp
# Entropy =  0.11728751547724937
# Cardinality =  14
# Rate =  0.0175992085122
# Solution time in seconds =  0.2247120370157063
#
#
# Solving problem 63 out of 900, for W = 0.017599999999999998 and N = 18 i = 2  j = 2
#
# Solver =  pulp
# Entropy =  0.12180141413623398
# Cardinality =  18
# Rate =  0.0175996839435
# Solution time in seconds =  0.1983390999957919
#
#
# Solving problem 64 out of 900, for W = 0.017599999999999998 and N = 22 i = 2  j = 3
#
# Solver =  pulp
# Entropy =  0.1251596200509095
# Cardinality =  22
# Rate =  0.0175999923314
# Solution time in seconds =  0.28748514998005703
#
#
# Solving problem 65 out of 900, for W = 0.017599999999999998 and N = 26 i = 2  j = 4
#
# Solver =  pulp
# Entropy =  0.12761678772230126
# Cardinality =  26
# Rate =  0.0175999280839
# Solution time in seconds =  0.27120063098846003
#
#
# Solving problem 66 out of 900, for W = 0.017599999999999998 and N = 30 i = 2  j = 5
#
# Solver =  pulp
# Entropy =  0.12992754677905174
# Cardinality =  30
# Rate =  0.0175992342112
# Solution time in seconds =  0.2089716520276852
#
#
# Solving problem 67 out of 900, for W = 0.017599999999999998 and N = 34 i = 2  j = 6
#
# Solver =  pulp
# Entropy =  0.13205631855476863
# Cardinality =  34
# Rate =  0.0175994783516
# Solution time in seconds =  0.2709215460345149
#
#
# Solving problem 68 out of 900, for W = 0.017599999999999998 and N = 38 i = 2  j = 7
#
# Solver =  pulp
# Entropy =  0.13415170621202482
# Cardinality =  38
# Rate =  0.0175989643718
# Solution time in seconds =  0.18292948295129463
#
#
# Solving problem 69 out of 900, for W = 0.017599999999999998 and N = 42 i = 2  j = 8
#
# Solver =  pulp
# Entropy =  0.13592316197878754
# Cardinality =  42
# Rate =  0.0175991314152
# Solution time in seconds =  0.30213999398984015
#
#
# Solving problem 70 out of 900, for W = 0.017599999999999998 and N = 46 i = 2  j = 9
#
# Solver =  pulp
# Entropy =  0.13762081537778173
# Cardinality =  46
# Rate =  0.0176000951274
# Solution time in seconds =  0.19290748197818175
#
#
# Solving problem 71 out of 900, for W = 0.017599999999999998 and N = 50 i = 2  j = 10
#
# Solver =  pulp
# Entropy =  0.13932471377426855
# Cardinality =  50
# Rate =  0.017598347596
# Solution time in seconds =  0.20091051299823448
#
#
# Solving problem 72 out of 900, for W = 0.017599999999999998 and N = 54 i = 2  j = 11
#
# Solver =  pulp
# Entropy =  0.1406081131309632
# Cardinality =  54
# Rate =  0.017599876686
# Solution time in seconds =  0.1937508140108548
#
#
# Solving problem 73 out of 900, for W = 0.017599999999999998 and N = 58 i = 2  j = 12
#
# Solver =  pulp
# Entropy =  0.1418660812889002
# Cardinality =  58
# Rate =  0.0175990286193
# Solution time in seconds =  0.19788422499550506
#
#
# Solving problem 74 out of 900, for W = 0.017599999999999998 and N = 62 i = 2  j = 13
#
# Solver =  pulp
# Entropy =  0.14307561756393253
# Cardinality =  62
# Rate =  0.0175994398031
# Solution time in seconds =  0.19389412796590477
#
#
# Solving problem 75 out of 900, for W = 0.017599999999999998 and N = 66 i = 2  j = 14
#
# Solver =  pulp
# Entropy =  0.14418471512492773
# Cardinality =  66
# Rate =  0.0175995297496
# Solution time in seconds =  0.20310925302328542
#
#
# Solving problem 76 out of 900, for W = 0.017599999999999998 and N = 70 i = 2  j = 15
#
# Solver =  pulp
# Entropy =  0.0
# Cardinality =  0
# Rate =  0
# Solution time in seconds =  0.26686943002277985
#
#
# Solving problem 77 out of 900, for W = 0.017599999999999998 and N = 74 i = 2  j = 16
#
# Solver =  pulp
# Entropy =  0.1462849776465579
# Cardinality =  74
# Rate =  0.0175994655021
# Solution time in seconds =  0.19508457003394142
#
#
# Solving problem 78 out of 900, for W = 0.017599999999999998 and N = 78 i = 2  j = 17
#
# Solver =  pulp
# Entropy =  0.1472750292502921
# Cardinality =  78
# Rate =  0.0175999152344
# Solution time in seconds =  0.2261004790198058
#
#
# Solving problem 79 out of 900, for W = 0.017599999999999998 and N = 82 i = 2  j = 18
#
# Solver =  pulp
# Entropy =  0.14821684405962846
# Cardinality =  82
# Rate =  0.0175995040506
# Solution time in seconds =  0.1788667289656587
#
#
# Solving problem 80 out of 900, for W = 0.017599999999999998 and N = 86 i = 2  j = 19
#
# Solver =  pulp
# Entropy =  0.1491232796037441
# Cardinality =  86
# Rate =  0.0176000437294
# Solution time in seconds =  0.20651779300533235
#
#
# Solving problem 81 out of 900, for W = 0.017599999999999998 and N = 90 i = 2  j = 20
#
# Solver =  pulp
# Entropy =  0.149990625648708
# Cardinality =  90
# Rate =  0.0175997353415
# Solution time in seconds =  0.21253690804587677
#
#
# Solving problem 82 out of 900, for W = 0.017599999999999998 and N = 94 i = 2  j = 21
#
# Solver =  pulp
# Entropy =  0.15080981914602737
# Cardinality =  94
# Rate =  0.017599876686
# Solution time in seconds =  0.24268527998356149
#
#
# Solving problem 83 out of 900, for W = 0.017599999999999998 and N = 98 i = 2  j = 22
#
# Solver =  pulp
# Entropy =  0.15156307232288505
# Cardinality =  98
# Rate =  0.0175994655021
# Solution time in seconds =  0.21974583598785102
#
#
# Solving problem 84 out of 900, for W = 0.017599999999999998 and N = 102 i = 2  j = 23
#
# Solver =  pulp
# Entropy =  0.15227986217744227
# Cardinality =  102
# Rate =  0.0175999923314
# Solution time in seconds =  0.18559200695017353
#
#
# Solving problem 85 out of 900, for W = 0.017599999999999998 and N = 106 i = 2  j = 24
#
# Solver =  pulp
# Entropy =  0.15295944061928865
# Cardinality =  106
# Rate =  0.0175996068466
# Solution time in seconds =  0.18926697399001569
#
#
# Solving problem 86 out of 900, for W = 0.017599999999999998 and N = 110 i = 2  j = 25
#
# Solver =  pulp
# Entropy =  0.15358734547168837
# Cardinality =  110
# Rate =  0.017599902385
# Solution time in seconds =  0.22796103300061077
#
#
# Solving problem 87 out of 900, for W = 0.017599999999999998 and N = 114 i = 2  j = 26
#
# Solver =  pulp
# Entropy =  0.15421108006396742
# Cardinality =  114
# Rate =  0.0175994655021
# Solution time in seconds =  0.18136166199110448
#
#
# Solving problem 88 out of 900, for W = 0.017599999999999998 and N = 118 i = 2  j = 27
#
# Solver =  pulp
# Entropy =  0.15480694522592753
# Cardinality =  118
# Rate =  0.0175998895355
# Solution time in seconds =  0.14986570598557591
#
#
# Solving problem 89 out of 900, for W = 0.017599999999999998 and N = 122 i = 2  j = 28
#
# Solver =  pulp
# Entropy =  0.1553742478990567
# Cardinality =  122
# Rate =  0.0175993241577
# Solution time in seconds =  0.175155793025624
#
#
# Solving problem 90 out of 900, for W = 0.017599999999999998 and N = 126 i = 2  j = 29
#
# Solver =  pulp
# Entropy =  0.15590614946731743
# Cardinality =  126
# Rate =  0.0175989129738
# Solution time in seconds =  0.2251535609830171
#
#
# Solving problem 91 out of 900, for W = 0.025899999999999996 and N = 10 i = 3  j = 0
#
# Solver =  pulp
# Entropy =  0.153849588838072
# Cardinality =  10
# Rate =  0.0258985819143
# Solution time in seconds =  0.2692901260452345
#
#
# Solving problem 92 out of 900, for W = 0.025899999999999996 and N = 14 i = 3  j = 1
#
# Solver =  pulp
# Entropy =  0.16276016052368134
# Cardinality =  14
# Rate =  0.0258963975001
# Solution time in seconds =  0.20143357204506174
#
#
# Solving problem 93 out of 900, for W = 0.025899999999999996 and N = 18 i = 3  j = 2
#
# Solver =  pulp
# Entropy =  0.0
# Cardinality =  0
# Rate =  0
# Solution time in seconds =  0.1918987960088998
#
#
# Solving problem 94 out of 900, for W = 0.025899999999999996 and N = 22 i = 3  j = 3
#
# Solver =  pulp
# Entropy =  0.17413700238657392
# Cardinality =  22
# Rate =  0.0258998026163
# Solution time in seconds =  0.18727706198114902
#
#
# Solving problem 95 out of 900, for W = 0.025899999999999996 and N = 26 i = 3  j = 4
#
# Solver =  pulp
# Entropy =  0.1786336468931361
# Cardinality =  26
# Rate =  0.0258998797133
# Solution time in seconds =  0.17824116203701124
#
#
# Solving problem 96 out of 900, for W = 0.025899999999999996 and N = 30 i = 3  j = 5
#
# Solver =  pulp
# Entropy =  0.0
# Cardinality =  0
# Rate =  0
# Solution time in seconds =  0.31666096101980656
#
#
# Solving problem 97 out of 900, for W = 0.025899999999999996 and N = 34 i = 3  j = 6
#
# Solver =  pulp
# Entropy =  0.18485385238793206
# Cardinality =  34
# Rate =  0.0258994685295
# Solution time in seconds =  0.3671042459900491
#
#
# Solving problem 98 out of 900, for W = 0.025899999999999996 and N = 38 i = 3  j = 7
#
# Solver =  pulp
# Entropy =  0.1874041339594611
# Cardinality =  38
# Rate =  0.0258982992254
# Solution time in seconds =  0.1845515840104781
#
#
# Solving problem 99 out of 900, for W = 0.025899999999999996 and N = 42 i = 3  j = 8
#
# Solver =  pulp
# Entropy =  0.1896115436236552
# Cardinality =  42
# Rate =  0.0258982606769
# Solution time in seconds =  0.27804868697421625
#
#
# Solving problem 100 out of 900, for W = 0.025899999999999996 and N = 46 i = 3  j = 9
#
# Solver =  pulp
# Entropy =  0.19179219637630765
# Cardinality =  46
# Rate =  0.0259001238537
# Solution time in seconds =  0.18862408702261746
#
#
# Solving problem 101 out of 900, for W = 0.025899999999999996 and N = 50 i = 3  j = 10
#
# Solver =  pulp
# Entropy =  0.19366279173090856
# Cardinality =  50
# Rate =  0.0258993143355
# Solution time in seconds =  0.24851680197753012
#
#
# Solving problem 102 out of 900, for W = 0.025899999999999996 and N = 54 i = 3  j = 11
#
# Solver =  pulp
# Entropy =  0.19543931594273173
# Cardinality =  54
# Rate =  0.025899352884
# Solution time in seconds =  0.24814608501037583
#
#
# Solving problem 103 out of 900, for W = 0.025899999999999996 and N = 58 i = 3  j = 12
#
# Solver =  pulp
# Entropy =  0.1971586411238227
# Cardinality =  58
# Rate =  0.0258999825093
# Solution time in seconds =  0.23903140402399004
#
#
# Solving problem 104 out of 900, for W = 0.025899999999999996 and N = 62 i = 3  j = 13
#
# Solver =  pulp
# Entropy =  0.1988345036146018
# Cardinality =  62
# Rate =  0.0258999439608
# Solution time in seconds =  0.21299178304616362
#
#
# Solving problem 105 out of 900, for W = 0.025899999999999996 and N = 66 i = 3  j = 14
#
# Solver =  pulp
# Entropy =  0.20033652192744317
# Cardinality =  66
# Rate =  0.0258992115395
# Solution time in seconds =  0.26288562797708437
#
#
# Solving problem 106 out of 900, for W = 0.025899999999999996 and N = 70 i = 3  j = 15
#
# Solver =  pulp
# Entropy =  0.20187449519919662
# Cardinality =  70
# Rate =  0.0258996484224
# Solution time in seconds =  0.27845753595465794
#
#
# Solving problem 107 out of 900, for W = 0.025899999999999996 and N = 74 i = 3  j = 16
#
# Solver =  pulp
# Entropy =  0.20338853789219333
# Cardinality =  74
# Rate =  0.0259001752517
# Solution time in seconds =  0.2627488790312782
#
#
# Solving problem 108 out of 900, for W = 0.025899999999999996 and N = 78 i = 3  j = 17
#
# Solver =  pulp
# Entropy =  0.20492494013418394
# Cardinality =  78
# Rate =  0.0258998540143
# Solution time in seconds =  0.2185310199856758
#
#
# Solving problem 109 out of 900, for W = 0.025899999999999996 and N = 82 i = 3  j = 18
#
# Solver =  pulp
# Entropy =  0.20643329337877864
# Cardinality =  82
# Rate =  0.0258988646032
# Solution time in seconds =  0.18058034998830408
#
#
# Solving problem 110 out of 900, for W = 0.025899999999999996 and N = 86 i = 3  j = 19
#
# Solver =  pulp
# Entropy =  0.20783986395570672
# Cardinality =  86
# Rate =  0.0258999953588
# Solution time in seconds =  0.22848993900697678
#
#
# Solving problem 111 out of 900, for W = 0.025899999999999996 and N = 90 i = 3  j = 20
#
# Solver =  pulp
# Entropy =  0.20920662932799658
# Cardinality =  90
# Rate =  0.0258998154658
# Solution time in seconds =  0.2108691029716283
#
#
# Solving problem 112 out of 900, for W = 0.025899999999999996 and N = 94 i = 3  j = 21
#
# Solver =  pulp
# Entropy =  0.21055067185923804
# Cardinality =  94
# Rate =  0.0258988903022
# Solution time in seconds =  0.22871797101106495
#
#
# Solving problem 113 out of 900, for W = 0.025899999999999996 and N = 98 i = 3  j = 22
#
# Solver =  pulp
# Entropy =  0.21170531095002706
# Cardinality =  98
# Rate =  0.0258996612719
# Solution time in seconds =  0.1802029280224815
#
#
# Solving problem 114 out of 900, for W = 0.025899999999999996 and N = 102 i = 3  j = 23
#
# Solver =  pulp
# Entropy =  0.21283495544194495
# Cardinality =  102
# Rate =  0.0259000339072
# Solution time in seconds =  0.21603880997281522
#
#
# Solving problem 115 out of 900, for W = 0.025899999999999996 and N = 106 i = 3  j = 24
#
# Solver =  pulp
# Entropy =  0.21389647631103065
# Cardinality =  106
# Rate =  0.0258999953588
# Solution time in seconds =  0.1675395520287566
#
#
# Solving problem 116 out of 900, for W = 0.025899999999999996 and N = 110 i = 3  j = 25
#
# Solver =  pulp
# Entropy =  0.21492210952845892
# Cardinality =  110
# Rate =  0.0258995327769
# Solution time in seconds =  0.19576303398935124
#
#
# Solving problem 117 out of 900, for W = 0.025899999999999996 and N = 114 i = 3  j = 26
#
# Solver =  pulp
# Entropy =  0.21591284739655298
# Cardinality =  114
# Rate =  0.0258994942284
# Solution time in seconds =  0.17178191000130028
#
#
# Solving problem 118 out of 900, for W = 0.025899999999999996 and N = 118 i = 3  j = 27
#
# Solver =  pulp
# Entropy =  0.21684236340212595
# Cardinality =  118
# Rate =  0.0258998925628
# Solution time in seconds =  0.25327116396510974
#
#
# Solving problem 119 out of 900, for W = 0.025899999999999996 and N = 122 i = 3  j = 28
#
# Solver =  pulp
# Entropy =  0.21774177043946033
# Cardinality =  122
# Rate =  0.025899404282
# Solution time in seconds =  0.25915757997427136
#
#
# Solving problem 120 out of 900, for W = 0.025899999999999996 and N = 126 i = 3  j = 29
#
# Solver =  pulp
# Entropy =  0.21863252081943502
# Cardinality =  126
# Rate =  0.0258997897668
# Solution time in seconds =  0.19766704097855836
#
#
# Solving problem 121 out of 900, for W = 0.034199999999999994 and N = 10 i = 4  j = 0
#
# Solver =  pulp
# Entropy =  0.0
# Cardinality =  0
# Rate =  0
# Solution time in seconds =  0.164157566963695
#
#
# Solving problem 122 out of 900, for W = 0.034199999999999994 and N = 14 i = 4  j = 1
#
# Solver =  pulp
# Entropy =  0.20502789083197787
# Cardinality =  14
# Rate =  0.0341969402062
# Solution time in seconds =  0.29642869700910524
#
#
# Solving problem 123 out of 900, for W = 0.034199999999999994 and N = 18 i = 4  j = 2
#
# Solver =  pulp
# Entropy =  0.0
# Cardinality =  0
# Rate =  0
# Solution time in seconds =  0.3020717860199511
#
#
# Solving problem 124 out of 900, for W = 0.034199999999999994 and N = 22 i = 4  j = 3
#
# Solver =  pulp
# Entropy =  0.22066397537371615
# Cardinality =  22
# Rate =  0.0341993302123
# Solution time in seconds =  0.3686142110382207
#
#
# Solving problem 125 out of 900, for W = 0.034199999999999994 and N = 26 i = 4  j = 4
#
# Solver =  pulp
# Entropy =  0.22602796256384003
# Cardinality =  26
# Rate =  0.0341997156972
# Solution time in seconds =  0.20131595997372642
#
#
# Solving problem 126 out of 900, for W = 0.034199999999999994 and N = 30 i = 4  j = 5
#
# Solver =  pulp
# Entropy =  0.23091323342008876
# Cardinality =  30
# Rate =  0.0341996129012
# Solution time in seconds =  0.18629977595992386
#
#
# Solving problem 127 out of 900, for W = 0.034199999999999994 and N = 34 i = 4  j = 6
#
# Solver =  pulp
# Entropy =  0.23501219942923085
# Cardinality =  34
# Rate =  0.0341992531154
# Solution time in seconds =  0.22199429897591472
#
#
# Solving problem 128 out of 900, for W = 0.034199999999999994 and N = 38 i = 4  j = 7
#
# Solver =  pulp
# Entropy =  0.23829448582143303
# Cardinality =  38
# Rate =  0.0341986620386
# Solution time in seconds =  0.19564053299836814
#
#
# Solving problem 129 out of 900, for W = 0.034199999999999994 and N = 42 i = 4  j = 8
#
# Solver =  pulp
# Entropy =  0.24115534822704165
# Cardinality =  42
# Rate =  0.0341995615033
# Solution time in seconds =  0.22458358795847744
#
#
# Solving problem 130 out of 900, for W = 0.034199999999999994 and N = 46 i = 4  j = 9
#
# Solver =  pulp
# Entropy =  0.24406770108144615
# Cardinality =  46
# Rate =  0.0341997028477
# Solution time in seconds =  0.17346040002303198
#
#
# Solving problem 131 out of 900, for W = 0.034199999999999994 and N = 50 i = 4  j = 10
#
# Solver =  pulp
# Entropy =  0.24654546685250459
# Cardinality =  50
# Rate =  0.034198931878
# Solution time in seconds =  0.22589108301326632
#
#
# Solving problem 132 out of 900, for W = 0.034199999999999994 and N = 54 i = 4  j = 11
#
# Solver =  pulp
# Entropy =  0.249022272496428
# Cardinality =  54
# Rate =  0.0341999598376
# Solution time in seconds =  0.18563914997503161
#
#
# Solving problem 133 out of 900, for W = 0.034199999999999994 and N = 58 i = 4  j = 12
#
# Solver =  pulp
# Entropy =  0.0
# Cardinality =  0
# Rate =  0
# Solution time in seconds =  0.21695798903238028
#
#
# Solving problem 134 out of 900, for W = 0.034199999999999994 and N = 62 i = 4  j = 13
#
# Solver =  pulp
# Entropy =  0.25295840283817844
# Cardinality =  62
# Rate =  0.0341991246204
# Solution time in seconds =  0.5385051719495095
#
#
# Solving problem 135 out of 900, for W = 0.034199999999999994 and N = 66 i = 4  j = 14
#
# Solver =  pulp
# Entropy =  0.25474704410707244
# Cardinality =  66
# Rate =  0.0341997413962
# Solution time in seconds =  1.857235524978023
#
#
# Solving problem 136 out of 900, for W = 0.034199999999999994 and N = 70 i = 4  j = 15
#
# Solver =  pulp
# Entropy =  0.2563911852847048
# Cardinality =  70
# Rate =  0.0341986748881
# Solution time in seconds =  0.18731763999676332
#
#
# Solving problem 137 out of 900, for W = 0.034199999999999994 and N = 74 i = 4  j = 16
#
# Solver =  pulp
# Entropy =  0.25806694194078217
# Cardinality =  74
# Rate =  0.0341996000517
# Solution time in seconds =  0.2669047040399164
#
#
# Solving problem 138 out of 900, for W = 0.034199999999999994 and N = 78 i = 4  j = 17
#
# Solver =  pulp
# Entropy =  0.259690109593443
# Cardinality =  78
# Rate =  0.0341981866073
# Solution time in seconds =  0.21169420500518754
#
#
# Solving problem 139 out of 900, for W = 0.034199999999999994 and N = 82 i = 4  j = 18
#
# Solver =  pulp
# Entropy =  0.2612831896014373
# Cardinality =  82
# Rate =  0.0341998570417
# Solution time in seconds =  0.19603122398257256
#
#
# Solving problem 140 out of 900, for W = 0.034199999999999994 and N = 86 i = 4  j = 19
#
# Solver =  pulp
# Entropy =  0.2628045002913699
# Cardinality =  86
# Rate =  0.0341998698911
# Solution time in seconds =  0.21850434003863484
#
#
# Solving problem 141 out of 900, for W = 0.034199999999999994 and N = 90 i = 4  j = 20
#
# Solver =  pulp
# Entropy =  0.26426422293509255
# Cardinality =  90
# Rate =  0.0341998827406
# Solution time in seconds =  0.1948143820045516
#
#
# Solving problem 142 out of 900, for W = 0.034199999999999994 and N = 94 i = 4  j = 21
#
# Solver =  pulp
# Entropy =  0.26571728263275096
# Cardinality =  94
# Rate =  0.0341996386002
# Solution time in seconds =  0.27231473400024697
#
#
# Solving problem 143 out of 900, for W = 0.034199999999999994 and N = 98 i = 4  j = 22
#
# Solver =  pulp
# Entropy =  0.26716406630349915
# Cardinality =  98
# Rate =  0.0341999598376
# Solution time in seconds =  0.3594463810441084
#
#
# Solving problem 144 out of 900, for W = 0.034199999999999994 and N = 102 i = 4  j = 23
#
# Solver =  pulp
# Entropy =  0.2685885796305179
# Cardinality =  102
# Rate =  0.0342000369346
# Solution time in seconds =  0.3486608219682239
#
#
# Solving problem 145 out of 900, for W = 0.034199999999999994 and N = 106 i = 4  j = 24
#
# Solver =  pulp
# Entropy =  0.26999954693639866
# Cardinality =  106
# Rate =  0.0341992531154
# Solution time in seconds =  0.27409295801771805
#
#
# Solving problem 146 out of 900, for W = 0.034199999999999994 and N = 110 i = 4  j = 25
#
# Solver =  pulp
# Entropy =  0.2714032112983572
# Cardinality =  110
# Rate =  0.0341993816103
# Solution time in seconds =  0.21085981401847675
#
#
# Solving problem 147 out of 900, for W = 0.034199999999999994 and N = 114 i = 4  j = 26
#
# Solver =  pulp
# Entropy =  0.27277050800170066
# Cardinality =  114
# Rate =  0.0341996000517
# Solution time in seconds =  0.16684847400756553
#
#
# Solving problem 148 out of 900, for W = 0.034199999999999994 and N = 118 i = 4  j = 27
#
# Solver =  pulp
# Entropy =  0.2740366984498437
# Cardinality =  118
# Rate =  0.0341997799447
# Solution time in seconds =  0.1906978790066205
#
#
# Solving problem 149 out of 900, for W = 0.034199999999999994 and N = 122 i = 4  j = 28
#
# Solver =  pulp
# Entropy =  0.2752798480407634
# Cardinality =  122
# Rate =  0.0342001140316
# Solution time in seconds =  0.2754803509451449
#
#
# Solving problem 150 out of 900, for W = 0.034199999999999994 and N = 126 i = 4  j = 29
#
# Solver =  pulp
# Entropy =  0.27654258781607793
# Cardinality =  126
# Rate =  0.0341998056437
# Solution time in seconds =  0.5217449870542623
#
#
# Solving problem 151 out of 900, for W = 0.042499999999999996 and N = 10 i = 5  j = 0
#
# Solver =  pulp
# Entropy =  0.2273881476431109
# Cardinality =  10
# Rate =  0.0416708106289
# Solution time in seconds =  0.1374397890176624
#
#
# Solving problem 152 out of 900, for W = 0.042499999999999996 and N = 14 i = 5  j = 1
#
# Solver =  pulp
# Entropy =  0.24499096367862322
# Cardinality =  14
# Rate =  0.0424891178909
# Solution time in seconds =  0.19313826697180048
#
#
# Solving problem 153 out of 900, for W = 0.042499999999999996 and N = 18 i = 5  j = 2
#
# Solver =  pulp
# Entropy =  0.25612858532254745
# Cardinality =  18
# Rate =  0.0424996416276
# Solution time in seconds =  0.25875459698727354
#
#
# Solving problem 154 out of 900, for W = 0.042499999999999996 and N = 22 i = 5  j = 3
#
# Solver =  pulp
# Entropy =  0.0
# Cardinality =  0
# Rate =  0
# Solution time in seconds =  0.2548019410460256
#
#
# Solving problem 155 out of 900, for W = 0.042499999999999996 and N = 26 i = 5  j = 4
#
# Solver =  pulp
# Entropy =  0.27177088351320633
# Cardinality =  26
# Rate =  0.0424989349053
# Solution time in seconds =  0.43638821301283315
#
#
# Solving problem 156 out of 900, for W = 0.042499999999999996 and N = 30 i = 5  j = 5
#
# Solver =  pulp
# Entropy =  0.27761000187806534
# Cardinality =  30
# Rate =  0.0424990248518
# Solution time in seconds =  0.1695085819810629
#
#
# Solving problem 157 out of 900, for W = 0.042499999999999996 and N = 34 i = 5  j = 6
#
# Solver =  pulp
# Entropy =  0.2826322825618991
# Cardinality =  34
# Rate =  0.042499731574
# Solution time in seconds =  0.31496291497023776
#
#
# Solving problem 158 out of 900, for W = 0.042499999999999996 and N = 38 i = 5  j = 7
#
# Solver =  pulp
# Entropy =  0.2874121373530796
# Cardinality =  38
# Rate =  0.0424998986175
# Solution time in seconds =  0.3640454870183021
#
#
# Solving problem 159 out of 900, for W = 0.042499999999999996 and N = 42 i = 5  j = 8
#
# Solver =  pulp
# Entropy =  0.29101925902035886
# Cardinality =  42
# Rate =  0.0425000528114
# Solution time in seconds =  0.2770350839709863
#
#
# Solving problem 160 out of 900, for W = 0.042499999999999996 and N = 46 i = 5  j = 9
#
# Solver =  pulp
# Entropy =  0.29419090559270733
# Cardinality =  46
# Rate =  0.0424999243165
# Solution time in seconds =  0.21903555101016536
#
#
# Solving problem 161 out of 900, for W = 0.042499999999999996 and N = 50 i = 5  j = 10
#
# Solver =  pulp
# Entropy =  0.29700961328117836
# Cardinality =  50
# Rate =  0.0424999757145
# Solution time in seconds =  0.1969260280020535
#
#
# Solving problem 162 out of 900, for W = 0.042499999999999996 and N = 54 i = 5  j = 11
#
# Solver =  pulp
# Entropy =  0.2999231181712605
# Cardinality =  54
# Rate =  0.0424990890993
# Solution time in seconds =  0.16484871500870213
#
#
# Solving problem 163 out of 900, for W = 0.042499999999999996 and N = 58 i = 5  j = 12
#
# Solver =  pulp
# Entropy =  0.3024015211677471
# Cardinality =  58
# Rate =  0.0424995645306
# Solution time in seconds =  0.27126076200511307
#
#
# Solving problem 164 out of 900, for W = 0.042499999999999996 and N = 62 i = 5  j = 13
#
# Solver =  pulp
# Entropy =  0.3048088936057784
# Cardinality =  62
# Rate =  0.0424985237215
# Solution time in seconds =  0.22643528500339016
#
#
# Solving problem 165 out of 900, for W = 0.042499999999999996 and N = 66 i = 5  j = 14
#
# Solver =  pulp
# Entropy =  0.3070166124052939
# Cardinality =  66
# Rate =  0.0424992689922
# Solution time in seconds =  0.23554766096640378
#
#
# Solving problem 166 out of 900, for W = 0.042499999999999996 and N = 70 i = 5  j = 15
#
# Solver =  pulp
# Entropy =  0.30926156362767815
# Cardinality =  70
# Rate =  0.0425000785104
# Solution time in seconds =  0.26265242899535224
#
#
# Solving problem 167 out of 900, for W = 0.042499999999999996 and N = 74 i = 5  j = 16
#
# Solver =  pulp
# Entropy =  0.3114095747905166
# Cardinality =  74
# Rate =  0.0425000399619
# Solution time in seconds =  0.2284492920152843
#
#
# Solving problem 168 out of 900, for W = 0.042499999999999996 and N = 78 i = 5  j = 17
#
# Solver =  pulp
# Entropy =  0.31315986230620346
# Cardinality =  78
# Rate =  0.0424993460892
# Solution time in seconds =  7.9693859340040945
#
#
# Solving problem 169 out of 900, for W = 0.042499999999999996 and N = 82 i = 5  j = 18
#
# Solver =  pulp
# Entropy =  0.3150350877477818
# Cardinality =  82
# Rate =  0.0424981639356
# Solution time in seconds =  0.24911059200530872
#
#
# Solving problem 170 out of 900, for W = 0.042499999999999996 and N = 86 i = 5  j = 19
#
# Solver =  pulp
# Entropy =  0.31680977990200193
# Cardinality =  86
# Rate =  0.0424993589387
# Solution time in seconds =  0.2074651889852248
#
#
# Solving problem 171 out of 900, for W = 0.042499999999999996 and N = 90 i = 5  j = 20
#
# Solver =  pulp
# Entropy =  0.3184874333506323
# Cardinality =  90
# Rate =  0.0424995773801
# Solution time in seconds =  0.20966762700118124
#
#
# Solving problem 172 out of 900, for W = 0.042499999999999996 and N = 94 i = 5  j = 21
#
# Solver =  pulp
# Entropy =  0.32014149330658637
# Cardinality =  94
# Rate =  0.0425000271124
# Solution time in seconds =  0.2554177310084924
#
#
# Solving problem 173 out of 900, for W = 0.042499999999999996 and N = 98 i = 5  j = 22
#
# Solver =  pulp
# Entropy =  0.321790738476779
# Cardinality =  98
# Rate =  0.0424998472195
# Solution time in seconds =  0.22571256995433941
#
#
# Solving problem 174 out of 900, for W = 0.042499999999999996 and N = 102 i = 5  j = 23
#
# Solver =  pulp
# Entropy =  0.3233128817558049
# Cardinality =  102
# Rate =  0.0424988321094
# Solution time in seconds =  0.2223842220264487
#
#
# Solving problem 175 out of 900, for W = 0.042499999999999996 and N = 106 i = 5  j = 24
#
# Solver =  pulp
# Entropy =  0.3248832654127
# Cardinality =  106
# Rate =  0.0424992175942
# Solution time in seconds =  0.1878960649482906
#
#
# Solving problem 176 out of 900, for W = 0.042499999999999996 and N = 110 i = 5  j = 25
#
# Solver =  pulp
# Entropy =  0.32632095959247587
# Cardinality =  110
# Rate =  0.0424997444235
# Solution time in seconds =  0.1929510229965672
#
#
# Solving problem 177 out of 900, for W = 0.042499999999999996 and N = 114 i = 5  j = 26
#
# Solver =  pulp
# Entropy =  0.32770879337769737
# Cardinality =  114
# Rate =  0.042499808671
# Solution time in seconds =  0.23436902300454676
#
#
# Solving problem 178 out of 900, for W = 0.042499999999999996 and N = 118 i = 5  j = 27
#
# Solver =  pulp
# Entropy =  0.3290421121705979
# Cardinality =  118
# Rate =  0.0424995516811
# Solution time in seconds =  0.2485423639882356
#
#
# Solving problem 179 out of 900, for W = 0.042499999999999996 and N = 122 i = 5  j = 28
#
# Solver =  pulp
# Entropy =  0.33043833363495967
# Cardinality =  122
# Rate =  0.0424995516811
# Solution time in seconds =  0.24308379500871524
#
#
# Solving problem 180 out of 900, for W = 0.042499999999999996 and N = 126 i = 5  j = 29
#
# Solver =  pulp
# Entropy =  0.0
# Cardinality =  0
# Rate =  0
# Solution time in seconds =  0.24451435002265498
#
#
# Solving problem 181 out of 900, for W = 0.05079999999999999 and N = 10 i = 6  j = 0
#
# Solver =  pulp
# Entropy =  0.2273881476431109
# Cardinality =  10
# Rate =  0.0416708106289
# Solution time in seconds =  0.13887572195380926
#
#
# Solving problem 182 out of 900, for W = 0.05079999999999999 and N = 14 i = 6  j = 1
#
# Solver =  pulp
# Entropy =  0.28326626017862433
# Cardinality =  14
# Rate =  0.0507983597054
# Solution time in seconds =  0.16240315895993263
#
#
# Solving problem 183 out of 900, for W = 0.05079999999999999 and N = 18 i = 6  j = 2
#
# Solver =  pulp
# Entropy =  0.2960689328835543
# Cardinality =  18
# Rate =  0.0507925260345
# Solution time in seconds =  0.220899470965378
#
#
# Solving problem 184 out of 900, for W = 0.05079999999999999 and N = 22 i = 6  j = 3
#
# Solver =  pulp
# Entropy =  0.3066788752579158
# Cardinality =  22
# Rate =  0.0507988736852
# Solution time in seconds =  0.22789608099265024
#
#
# Solving problem 185 out of 900, for W = 0.05079999999999999 and N = 26 i = 6  j = 4
#
# Solver =  pulp
# Entropy =  0.3156369297365039
# Cardinality =  26
# Rate =  0.0507988351367
# Solution time in seconds =  0.22663279599510133
#
#
# Solving problem 186 out of 900, for W = 0.05079999999999999 and N = 30 i = 6  j = 5
#
# Solver =  pulp
# Entropy =  0.3227381557926767
# Cardinality =  30
# Rate =  0.0507947875457
# Solution time in seconds =  0.15147631196305156
#
#
# Solving problem 187 out of 900, for W = 0.05079999999999999 and N = 34 i = 6  j = 6
#
# Solver =  pulp
# Entropy =  0.3285634919938076
# Cardinality =  34
# Rate =  0.0507988736852
# Solution time in seconds =  0.18820518197026104
#
#
# Solving problem 188 out of 900, for W = 0.05079999999999999 and N = 38 i = 6  j = 7
#
# Solver =  pulp
# Entropy =  0.3341236861775745
# Cardinality =  38
# Rate =  0.0507995675579
# Solution time in seconds =  0.1904827689868398
#
#
# Solving problem 189 out of 900, for W = 0.05079999999999999 and N = 42 i = 6  j = 8
#
# Solver =  pulp
# Entropy =  0.3391647396423649
# Cardinality =  42
# Rate =  0.0507991435246
# Solution time in seconds =  0.21058156801154837
#
#
# Solving problem 190 out of 900, for W = 0.05079999999999999 and N = 46 i = 6  j = 9
#
# Solver =  pulp
# Entropy =  0.34309426085040484
# Cardinality =  46
# Rate =  0.0507991178256
# Solution time in seconds =  0.22023332701064646
#
#
# Solving problem 191 out of 900, for W = 0.05079999999999999 and N = 50 i = 6  j = 10
#
# Solver =  pulp
# Entropy =  0.346460272646816
# Cardinality =  50
# Rate =  0.0507998116984
# Solution time in seconds =  0.33239909302210435
#
#
# Solving problem 192 out of 900, for W = 0.05079999999999999 and N = 54 i = 6  j = 11
#
# Solver =  pulp
# Entropy =  0.3496954589947006
# Cardinality =  54
# Rate =  0.0507997217519
# Solution time in seconds =  0.2535598180256784
#
#
# Solving problem 193 out of 900, for W = 0.05079999999999999 and N = 58 i = 6  j = 12
#
# Solver =  pulp
# Entropy =  0.3527641144674474
# Cardinality =  58
# Rate =  0.0507922690446
# Solution time in seconds =  0.14853299903916195
#
#
# Solving problem 194 out of 900, for W = 0.05079999999999999 and N = 62 i = 6  j = 13
#
# Solver =  pulp
# Entropy =  0.3554419497052386
# Cardinality =  62
# Rate =  0.0507982826084
# Solution time in seconds =  0.19039560802048072
#
#
# Solving problem 195 out of 900, for W = 0.05079999999999999 and N = 66 i = 6  j = 14
#
# Solver =  pulp
# Entropy =  0.35788156302968666
# Cardinality =  66
# Rate =  0.0507974473912
# Solution time in seconds =  0.5719471830525436
#
#
# Solving problem 196 out of 900, for W = 0.05079999999999999 and N = 70 i = 6  j = 15
#
# Solver =  pulp
# Entropy =  0.36026488902860915
# Cardinality =  70
# Rate =  0.0507992077721
# Solution time in seconds =  0.23250810703029856
#
#
# Solving problem 197 out of 900, for W = 0.05079999999999999 and N = 74 i = 6  j = 16
#
# Solver =  pulp
# Entropy =  0.36258828157263934
# Cardinality =  74
# Rate =  0.0508000044408
# Solution time in seconds =  0.20578669803217053
#
#
# Solving problem 198 out of 900, for W = 0.05079999999999999 and N = 78 i = 6  j = 17
#
# Solver =  pulp
# Entropy =  0.3648326684073589
# Cardinality =  78
# Rate =  0.0507977172306
# Solution time in seconds =  0.19650125596672297
#
#
# Solving problem 199 out of 900, for W = 0.05079999999999999 and N = 82 i = 6  j = 18
#
# Solver =  pulp
# Entropy =  0.36667219881379964
# Cardinality =  82
# Rate =  0.0507988479862
# Solution time in seconds =  0.38959852600237355
#
#
# Solving problem 200 out of 900, for W = 0.05079999999999999 and N = 86 i = 6  j = 19
#
# Solver =  pulp
# Entropy =  0.36847123413491395
# Cardinality =  86
# Rate =  0.0507998116984
# Solution time in seconds =  0.22190085297916085
#
#
# Solving problem 201 out of 900, for W = 0.05079999999999999 and N = 90 i = 6  j = 20
#
# Solver =  pulp
# Entropy =  0.37070850578080794
# Cardinality =  90
# Rate =  0.0508000558388
# Solution time in seconds =  0.1961337510147132
#
#
# Solving problem 202 out of 900, for W = 0.05079999999999999 and N = 94 i = 6  j = 21
#
# Solver =  pulp
# Entropy =  0.3723431844542133
# Cardinality =  94
# Rate =  0.050799541859
# Solution time in seconds =  0.25790763599798083
#
#
# Solving problem 203 out of 900, for W = 0.05079999999999999 and N = 98 i = 6  j = 22
#
# Solver =  pulp
# Entropy =  0.37412267471041394
# Cardinality =  98
# Rate =  0.0508000943873
# Solution time in seconds =  0.24585243500769138
#
#
# Solving problem 204 out of 900, for W = 0.05079999999999999 and N = 102 i = 6  j = 23
#
# Solver =  pulp
# Entropy =  0.3761157721020431
# Cardinality =  102
# Rate =  0.0507998116984
# Solution time in seconds =  0.20175533002475277
#
#
# Solving problem 205 out of 900, for W = 0.05079999999999999 and N = 106 i = 6  j = 24
#
# Solver =  pulp
# Entropy =  0.3776802923673435
# Cardinality =  106
# Rate =  0.0507993234175
# Solution time in seconds =  0.2059713579947129
#
#
# Solving problem 206 out of 900, for W = 0.05079999999999999 and N = 110 i = 6  j = 25
#
# Solver =  pulp
# Entropy =  0.3795060913393073
# Cardinality =  110
# Rate =  0.0507996061064
# Solution time in seconds =  0.3043532169540413
#
#
# Solving problem 207 out of 900, for W = 0.05079999999999999 and N = 114 i = 6  j = 26
#
# Solver =  pulp
# Entropy =  0.38119747043367985
# Cardinality =  114
# Rate =  0.0507986423943
# Solution time in seconds =  0.2590612010098994
#
#
# Solving problem 208 out of 900, for W = 0.05079999999999999 and N = 118 i = 6  j = 27
#
# Solver =  pulp
# Entropy =  0.38277610095123055
# Cardinality =  118
# Rate =  0.0508000558388
# Solution time in seconds =  0.22932342399144545
#
#
# Solving problem 209 out of 900, for W = 0.05079999999999999 and N = 122 i = 6  j = 28
#
# Solver =  pulp
# Entropy =  0.38461360886572793
# Cardinality =  122
# Rate =  0.0507998887953
# Solution time in seconds =  0.24913301097694784
#
#
# Solving problem 210 out of 900, for W = 0.05079999999999999 and N = 126 i = 6  j = 29
#
# Solver =  pulp
# Entropy =  0.38596674479391707
# Cardinality =  126
# Rate =  0.0507997346014
# Solution time in seconds =  0.20695367298321798
#
#
# Solving problem 211 out of 900, for W = 0.059099999999999986 and N = 10 i = 7  j = 0
#
# Solver =  pulp
# Entropy =  0.2273881476431109
# Cardinality =  10
# Rate =  0.0416708106289
# Solution time in seconds =  0.14061497402144596
#
#
# Solving problem 212 out of 900, for W = 0.059099999999999986 and N = 14 i = 7  j = 1
#
# Solver =  pulp
# Entropy =  0.28979355497671533
# Cardinality =  14
# Rate =  0.0521723305443
# Solution time in seconds =  0.14030802296474576
#
#
# Solving problem 213 out of 900, for W = 0.059099999999999986 and N = 18 i = 7  j = 2
#
# Solver =  pulp
# Entropy =  0.33489099099551567
# Cardinality =  18
# Rate =  0.0590189785504
# Solution time in seconds =  0.15512795298127457
#
#
# Solving problem 214 out of 900, for W = 0.059099999999999986 and N = 22 i = 7  j = 3
#
# Solver =  pulp
# Entropy =  0.34684164182160876
# Cardinality =  22
# Rate =  0.0590988253146
# Solution time in seconds =  0.24557984597049654
#
#
# Solving problem 215 out of 900, for W = 0.059099999999999986 and N = 26 i = 7  j = 4
#
# Solver =  pulp
# Entropy =  0.35693053626539967
# Cardinality =  26
# Rate =  0.0590982470873
# Solution time in seconds =  2.9360567909898236
#
#
# Solving problem 216 out of 900, for W = 0.059099999999999986 and N = 30 i = 7  j = 5
#
# Solver =  pulp
# Entropy =  0.36649191016273713
# Cardinality =  30
# Rate =  0.0590964738569
# Solution time in seconds =  0.17333419801434502
#
#
# ...
#
# Solver =  pulp
# Entropy =  0.8198038462440013
# Cardinality =  86
# Rate =  0.131635652868
# Solution time in seconds =  0.18194127804599702
#
#
# Solving problem 831 out of 900, for W = 0.22509999999999997 and N = 90 i = 27  j = 20
#
# Solver =  pulp
# Entropy =  0.8314995428924994
# Cardinality =  90
# Rate =  0.133115773388
# Solution time in seconds =  0.18177449802169576
#
#
# Solving problem 832 out of 900, for W = 0.22509999999999997 and N = 94 i = 27  j = 21
#
# Solver =  pulp
# Entropy =  0.8424032458461146
# Cardinality =  94
# Rate =  0.134481816088
# Solution time in seconds =  0.18212342396145687
#
#
# Solving problem 833 out of 900, for W = 0.22509999999999997 and N = 98 i = 27  j = 22
#
# Solver =  pulp
# Entropy =  0.8527541032548464
# Cardinality =  98
# Rate =  0.135769027134
# Solution time in seconds =  0.18505751801421866
#
#
# Solving problem 834 out of 900, for W = 0.22509999999999997 and N = 102 i = 27  j = 23
#
# Solver =  pulp
# Entropy =  0.8619593018469673
# Cardinality =  102
# Rate =  0.13689507981
# Solution time in seconds =  0.18273278698325157
#
#
# Solving problem 835 out of 900, for W = 0.22509999999999997 and N = 106 i = 27  j = 24
#
# Solver =  pulp
# Entropy =  0.8705212752989271
# Cardinality =  106
# Rate =  0.137931956988
# Solution time in seconds =  0.1854000890161842
#
#
# Solving problem 836 out of 900, for W = 0.22509999999999997 and N = 110 i = 27  j = 25
#
# Solver =  pulp
# Entropy =  0.8787853886071626
# Cardinality =  110
# Rate =  0.138927869975
# Solution time in seconds =  0.18251013394910842
#
#
# Solving problem 837 out of 900, for W = 0.22509999999999997 and N = 114 i = 27  j = 26
#
# Solver =  pulp
# Entropy =  0.8865481100655087
# Cardinality =  114
# Rate =  0.139855410797
# Solution time in seconds =  0.18318423995515332
#
#
# Solving problem 838 out of 900, for W = 0.22509999999999997 and N = 118 i = 27  j = 27
#
# Solver =  pulp
# Entropy =  0.8940051952803563
# Cardinality =  118
# Rate =  0.140741614792
# Solution time in seconds =  0.18350934999762103
#
#
# Solving problem 839 out of 900, for W = 0.22509999999999997 and N = 122 i = 27  j = 28
#
# Solver =  pulp
# Entropy =  0.9011281852569532
# Cardinality =  122
# Rate =  0.141582896952
# Solution time in seconds =  0.18154143798165023
#
#
# Solving problem 840 out of 900, for W = 0.22509999999999997 and N = 126 i = 27  j = 29
#
# Solver =  pulp
# Entropy =  0.9080871165423782
# Cardinality =  126
# Rate =  0.142402245023
# Solution time in seconds =  0.1815103580011055
#
#
# Solving problem 841 out of 900, for W = 0.23339999999999994 and N = 10 i = 28  j = 0
#
# Solver =  pulp
# Entropy =  0.2273881476431109
# Cardinality =  10
# Rate =  0.0416708106289
# Solution time in seconds =  0.17894139396958053
#
#
# Solving problem 842 out of 900, for W = 0.23339999999999994 and N = 14 i = 28  j = 1
#
# Solver =  pulp
# Entropy =  0.28979355497671533
# Cardinality =  14
# Rate =  0.0521723305443
# Solution time in seconds =  0.1802002090262249
#
#
# Solving problem 843 out of 900, for W = 0.23339999999999994 and N = 18 i = 28  j = 2
#
# Solver =  pulp
# Entropy =  0.34824705921058374
# Cardinality =  18
# Rate =  0.061883953432
# Solution time in seconds =  0.1803671300294809
#
#
# Solving problem 844 out of 900, for W = 0.23339999999999994 and N = 22 i = 28  j = 3
#
# Solver =  pulp
# Entropy =  0.3984150034752807
# Cardinality =  22
# Rate =  0.0699732247356
# Solution time in seconds =  0.18033381598070264
#
#
# Solving problem 845 out of 900, for W = 0.23339999999999994 and N = 26 i = 28  j = 4
#
# Solver =  pulp
# Entropy =  0.4448140801387055
# Cardinality =  26
# Rate =  0.0773420248348
# Solution time in seconds =  0.18151643499732018
#
#
# Solving problem 846 out of 900, for W = 0.23339999999999994 and N = 30 i = 28  j = 5
#
# Solver =  pulp
# Entropy =  0.48712410185392274
# Cardinality =  30
# Rate =  0.0839490040536
# Solution time in seconds =  0.1809074209886603
#
#
# Solving problem 847 out of 900, for W = 0.23339999999999994 and N = 34 i = 28  j = 6
#
# Solver =  pulp
# Entropy =  0.5258788222273968
# Cardinality =  34
# Rate =  0.089901969658
# Solution time in seconds =  0.18197515100473538
#
#
# Solving problem 848 out of 900, for W = 0.23339999999999994 and N = 38 i = 28  j = 7
#
# Solver =  pulp
# Entropy =  0.5636480365304316
# Cardinality =  38
# Rate =  0.0956766870629
# Solution time in seconds =  0.18151315295835957
#
#
# Solving problem 849 out of 900, for W = 0.23339999999999994 and N = 42 i = 28  j = 8
#
# Solver =  pulp
# Entropy =  0.5980269751091708
# Cardinality =  42
# Rate =  0.100849881042
# Solution time in seconds =  0.18256223597563803
#
#
# Solving problem 850 out of 900, for W = 0.23339999999999994 and N = 46 i = 28  j = 9
#
# Solver =  pulp
# Entropy =  0.6263493016376022
# Cardinality =  46
# Rate =  0.104967925861
# Solution time in seconds =  0.1796407820074819
#
#
# Solving problem 851 out of 900, for W = 0.23339999999999994 and N = 50 i = 28  j = 10
#
# Solver =  pulp
# Entropy =  0.652396432016716
# Cardinality =  50
# Rate =  0.108701372434
# Solution time in seconds =  0.18330324901035056
#
#
# Solving problem 852 out of 900, for W = 0.23339999999999994 and N = 54 i = 28  j = 11
#
# Solver =  pulp
# Entropy =  0.6778314996803736
# Cardinality =  54
# Rate =  0.112332678369
# Solution time in seconds =  0.1793857230222784
#
#
# Solving problem 853 out of 900, for W = 0.23339999999999994 and N = 58 i = 28  j = 12
#
# Solver =  pulp
# Entropy =  0.7028129723866844
# Cardinality =  58
# Rate =  0.115888532067
# Solution time in seconds =  0.18303498899331316
#
#
# Solving problem 854 out of 900, for W = 0.23339999999999994 and N = 62 i = 28  j = 13
#
# Solver =  pulp
# Entropy =  0.727353464370005
# Cardinality =  62
# Rate =  0.119371349234
# Solution time in seconds =  0.18596726801479235
#
#
# Solving problem 855 out of 900, for W = 0.23339999999999994 and N = 66 i = 28  j = 14
#
# Solver =  pulp
# Entropy =  0.750991980964923
# Cardinality =  66
# Rate =  0.122705561986
# Solution time in seconds =  0.180122475954704
#
#
# Solving problem 856 out of 900, for W = 0.23339999999999994 and N = 70 i = 28  j = 15
#
# Solver =  pulp
# Entropy =  0.7671456185090574
# Cardinality =  70
# Rate =  0.124850631041
# Solution time in seconds =  0.18284027295885608
#
#
# Solving problem 857 out of 900, for W = 0.23339999999999994 and N = 74 i = 28  j = 16
#
# Solver =  pulp
# Entropy =  0.7820483514842841
# Cardinality =  74
# Rate =  0.126805578963
# Solution time in seconds =  0.18209939904045314
#
#
# Solving problem 858 out of 900, for W = 0.23339999999999994 and N = 78 i = 28  j = 17
#
# Solver =  pulp
# Entropy =  0.7951757641374687
# Cardinality =  78
# Rate =  0.128495274752
# Solution time in seconds =  0.18165011098608375
#
#
# Solving problem 859 out of 900, for W = 0.23339999999999994 and N = 82 i = 28  j = 18
#
# Solver =  pulp
# Entropy =  0.8077741963876375
# Cardinality =  82
# Rate =  0.130106999804
# Solution time in seconds =  0.18126305099576712
#
#
# Solving problem 860 out of 900, for W = 0.23339999999999994 and N = 86 i = 28  j = 19
#
# Solver =  pulp
# Entropy =  0.8198038462440013
# Cardinality =  86
# Rate =  0.131635652868
# Solution time in seconds =  0.18148172297514975
#
#
# Solving problem 861 out of 900, for W = 0.23339999999999994 and N = 90 i = 28  j = 20
#
# Solver =  pulp
# Entropy =  0.8314995428924994
# Cardinality =  90
# Rate =  0.133115773388
# Solution time in seconds =  0.18371496204053983
#
#
# Solving problem 862 out of 900, for W = 0.23339999999999994 and N = 94 i = 28  j = 21
#
# Solver =  pulp
# Entropy =  0.8424032458461146
# Cardinality =  94
# Rate =  0.134481816088
# Solution time in seconds =  0.18068902799859643
#
#
# Solving problem 863 out of 900, for W = 0.23339999999999994 and N = 98 i = 28  j = 22
#
# Solver =  pulp
# Entropy =  0.8527541032548464
# Cardinality =  98
# Rate =  0.135769027134
# Solution time in seconds =  0.18479358800686896
#
#
# Solving problem 864 out of 900, for W = 0.23339999999999994 and N = 102 i = 28  j = 23
#
# Solver =  pulp
# Entropy =  0.8619593018469673
# Cardinality =  102
# Rate =  0.13689507981
# Solution time in seconds =  0.1799571629962884
#
#
# Solving problem 865 out of 900, for W = 0.23339999999999994 and N = 106 i = 28  j = 24
#
# Solver =  pulp
# Entropy =  0.8705212752989271
# Cardinality =  106
# Rate =  0.137931956988
# Solution time in seconds =  0.18206818000180647
#
#
# Solving problem 866 out of 900, for W = 0.23339999999999994 and N = 110 i = 28  j = 25
#
# Solver =  pulp
# Entropy =  0.8787853886071626
# Cardinality =  110
# Rate =  0.138927869975
# Solution time in seconds =  0.182613777986262
#
#
# Solving problem 867 out of 900, for W = 0.23339999999999994 and N = 114 i = 28  j = 26
#
# Solver =  pulp
# Entropy =  0.8865481100655087
# Cardinality =  114
# Rate =  0.139855410797
# Solution time in seconds =  0.1819372969912365
#
#
# Solving problem 868 out of 900, for W = 0.23339999999999994 and N = 118 i = 28  j = 27
#
# Solver =  pulp
# Entropy =  0.8940051952803563
# Cardinality =  118
# Rate =  0.140741614792
# Solution time in seconds =  0.1831769059645012
#
#
# Solving problem 869 out of 900, for W = 0.23339999999999994 and N = 122 i = 28  j = 28
#
# Solver =  pulp
# Entropy =  0.9011281852569532
# Cardinality =  122
# Rate =  0.141582896952
# Solution time in seconds =  0.18227700499119237
#
#
# Solving problem 870 out of 900, for W = 0.23339999999999994 and N = 126 i = 28  j = 29
#
# Solver =  pulp
# Entropy =  0.9080871165423782
# Cardinality =  126
# Rate =  0.142402245023
# Solution time in seconds =  0.18348022701684386
#
#
# Solving problem 871 out of 900, for W = 0.24169999999999994 and N = 10 i = 29  j = 0
#
# Solver =  pulp
# Entropy =  0.2273881476431109
# Cardinality =  10
# Rate =  0.0416708106289
# Solution time in seconds =  0.18113887397339568
#
#
# Solving problem 872 out of 900, for W = 0.24169999999999994 and N = 14 i = 29  j = 1
#
# Solver =  pulp
# Entropy =  0.28979355497671533
# Cardinality =  14
# Rate =  0.0521723305443
# Solution time in seconds =  0.18108747096266598
#
#
# Solving problem 873 out of 900, for W = 0.24169999999999994 and N = 18 i = 29  j = 2
#
# Solver =  pulp
# Entropy =  0.34824705921058374
# Cardinality =  18
# Rate =  0.061883953432
# Solution time in seconds =  0.18283671099925414
#
#
# Solving problem 874 out of 900, for W = 0.24169999999999994 and N = 22 i = 29  j = 3
#
# Solver =  pulp
# Entropy =  0.3984150034752807
# Cardinality =  22
# Rate =  0.0699732247356
# Solution time in seconds =  0.18338461400708184
#
#
# Solving problem 875 out of 900, for W = 0.24169999999999994 and N = 26 i = 29  j = 4
#
# Solver =  pulp
# Entropy =  0.4448140801387055
# Cardinality =  26
# Rate =  0.0773420248348
# Solution time in seconds =  0.18380834098206833
#
#
# Solving problem 876 out of 900, for W = 0.24169999999999994 and N = 30 i = 29  j = 5
#
# Solver =  pulp
# Entropy =  0.48712410185392274
# Cardinality =  30
# Rate =  0.0839490040536
# Solution time in seconds =  0.1824638299876824
#
#
# Solving problem 877 out of 900, for W = 0.24169999999999994 and N = 34 i = 29  j = 6
#
# Solver =  pulp
# Entropy =  0.5258788222273968
# Cardinality =  34
# Rate =  0.089901969658
# Solution time in seconds =  0.18271469901083037
#
#
# Solving problem 878 out of 900, for W = 0.24169999999999994 and N = 38 i = 29  j = 7
#
# Solver =  pulp
# Entropy =  0.5636480365304316
# Cardinality =  38
# Rate =  0.0956766870629
# Solution time in seconds =  0.18039380898699164
#
#
# Solving problem 879 out of 900, for W = 0.24169999999999994 and N = 42 i = 29  j = 8
#
# Solver =  pulp
# Entropy =  0.5980269751091708
# Cardinality =  42
# Rate =  0.100849881042
# Solution time in seconds =  0.18079958599992096
#
#
# Solving problem 880 out of 900, for W = 0.24169999999999994 and N = 46 i = 29  j = 9
#
# Solver =  pulp
# Entropy =  0.6263493016376022
# Cardinality =  46
# Rate =  0.104967925861
# Solution time in seconds =  0.17943684698548168
#
#
# Solving problem 881 out of 900, for W = 0.24169999999999994 and N = 50 i = 29  j = 10
#
# Solver =  pulp
# Entropy =  0.652396432016716
# Cardinality =  50
# Rate =  0.108701372434
# Solution time in seconds =  0.180969579028897
#
#
# Solving problem 882 out of 900, for W = 0.24169999999999994 and N = 54 i = 29  j = 11
#
# Solver =  pulp
# Entropy =  0.6778314996803736
# Cardinality =  54
# Rate =  0.112332678369
# Solution time in seconds =  0.18090972496429458
#
#
# Solving problem 883 out of 900, for W = 0.24169999999999994 and N = 58 i = 29  j = 12
#
# Solver =  pulp
# Entropy =  0.7028129723866844
# Cardinality =  58
# Rate =  0.115888532067
# Solution time in seconds =  0.17924038297496736
#
#
# Solving problem 884 out of 900, for W = 0.24169999999999994 and N = 62 i = 29  j = 13
#
# Solver =  pulp
# Entropy =  0.727353464370005
# Cardinality =  62
# Rate =  0.119371349234
# Solution time in seconds =  0.18126172403572127
#
#
# Solving problem 885 out of 900, for W = 0.24169999999999994 and N = 66 i = 29  j = 14
#
# Solver =  pulp
# Entropy =  0.750991980964923
# Cardinality =  66
# Rate =  0.122705561986
# Solution time in seconds =  0.18194665596820414
#
#
# Solving problem 886 out of 900, for W = 0.24169999999999994 and N = 70 i = 29  j = 15
#
# Solver =  pulp
# Entropy =  0.7671456185090574
# Cardinality =  70
# Rate =  0.124850631041
# Solution time in seconds =  0.1806529900059104
#
#
# Solving problem 887 out of 900, for W = 0.24169999999999994 and N = 74 i = 29  j = 16
#
# Solver =  pulp
# Entropy =  0.7820483514842841
# Cardinality =  74
# Rate =  0.126805578963
# Solution time in seconds =  0.18038144696038216
#
#
# Solving problem 888 out of 900, for W = 0.24169999999999994 and N = 78 i = 29  j = 17
#
# Solver =  pulp
# Entropy =  0.7951757641374687
# Cardinality =  78
# Rate =  0.128495274752
# Solution time in seconds =  0.1799656130024232
#
#
# Solving problem 889 out of 900, for W = 0.24169999999999994 and N = 82 i = 29  j = 18
#
# Solver =  pulp
# Entropy =  0.8077741963876375
# Cardinality =  82
# Rate =  0.130106999804
# Solution time in seconds =  0.18131766800070181
#
#
# Solving problem 890 out of 900, for W = 0.24169999999999994 and N = 86 i = 29  j = 19
#
# Solver =  pulp
# Entropy =  0.8198038462440013
# Cardinality =  86
# Rate =  0.131635652868
# Solution time in seconds =  0.18992823601001874
#
#
# Solving problem 891 out of 900, for W = 0.24169999999999994 and N = 90 i = 29  j = 20
#
# Solver =  pulp
# Entropy =  0.8314995428924994
# Cardinality =  90
# Rate =  0.133115773388
# Solution time in seconds =  0.1848225729772821
#
#
# Solving problem 892 out of 900, for W = 0.24169999999999994 and N = 94 i = 29  j = 21
#
# Solver =  pulp
# Entropy =  0.8424032458461146
# Cardinality =  94
# Rate =  0.134481816088
# Solution time in seconds =  0.189177653985098
#
#
# Solving problem 893 out of 900, for W = 0.24169999999999994 and N = 98 i = 29  j = 22
#
# Solver =  pulp
# Entropy =  0.8527541032548464
# Cardinality =  98
# Rate =  0.135769027134
# Solution time in seconds =  0.18504746101098135
#
#
# Solving problem 894 out of 900, for W = 0.24169999999999994 and N = 102 i = 29  j = 23
#
# Solver =  pulp
# Entropy =  0.8619593018469673
# Cardinality =  102
# Rate =  0.13689507981
# Solution time in seconds =  0.187502934015356
#
#
# Solving problem 895 out of 900, for W = 0.24169999999999994 and N = 106 i = 29  j = 24
#
# Solver =  pulp
# Entropy =  0.8705212752989271
# Cardinality =  106
# Rate =  0.137931956988
# Solution time in seconds =  0.18620710301911458
#
#
# Solving problem 896 out of 900, for W = 0.24169999999999994 and N = 110 i = 29  j = 25
#
# Solver =  pulp
# Entropy =  0.8787853886071626
# Cardinality =  110
# Rate =  0.138927869975
# Solution time in seconds =  0.18300405098125339
#
#
# Solving problem 897 out of 900, for W = 0.24169999999999994 and N = 114 i = 29  j = 26
#
# Solver =  pulp
# Entropy =  0.8865481100655087
# Cardinality =  114
# Rate =  0.139855410797
# Solution time in seconds =  0.18688148795627058
#
#
# Solving problem 898 out of 900, for W = 0.24169999999999994 and N = 118 i = 29  j = 27
#
# Solver =  pulp
# Entropy =  0.8940051952803563
# Cardinality =  118
# Rate =  0.140741614792
# Solution time in seconds =  0.18555723101599142
#
#
# Solving problem 899 out of 900, for W = 0.24169999999999994 and N = 122 i = 29  j = 28
#
# Solver =  pulp
# Entropy =  0.9011281852569532
# Cardinality =  122
# Rate =  0.141582896952
# Solution time in seconds =  0.18273872399004176
#
#
# Solving problem 900 out of 900, for W = 0.24169999999999994 and N = 126 i = 29  j = 29
#
# Solver =  pulp
# Entropy =  0.9080871165423782
# Cardinality =  126
# Rate =  0.142402245023
# Solution time in seconds =  0.18320435500936583

# %%
zeroindexes = (entropies == 0).nonzero()
totzeros = len(zeroindexes[0])
zeroindexes = zip(zeroindexes[0], zeroindexes[1])
for i,j in zeroindexes:
    print(i,j,totzeros)
# Out:
# 1 0 23
# 2 15 23
# 3 2 23
# 3 5 23
# 4 0 23
# 4 2 23
# 4 12 23
# 5 3 23
# 5 29 23
# 7 8 23
# 8 9 23
# 8 10 23
# 8 21 23
# 8 27 23
# 8 29 23
# 9 22 23
# 10 8 23
# 10 20 23
# 13 11 23
# 13 20 23
# 13 21 23
# 14 20 23
# 16 29 23

# %%
#RECALCULATE SOLUTIONS NOT SOLVED BY PULP WITH GLPK
zeroindexes = (entropies == 0).nonzero()
totzeros = len(zeroindexes[0])
zeroindexes = zip(zeroindexes[0], zeroindexes[1])
it = 0
for i,j in zeroindexes:
    print("\n\nSolving problem {0} out of {1}, for W = {2} and N = {3} i = {4}  j = {5}".format(it, totzeros, Wrange[i], Nrange[j],i,j))
    glpsol = BPV.BPV("glpk",data,Nrange[j],Wrange[i],time_solver=True)
    glpsol.solve()
    entropies[i,j] = glpsol.solution_entropy
    rates[i,j] = glpsol.solution_rate
    cardinalities[i,j] = glpsol.solution_cardinality
    indexes[(i,j)] = glpsol.solution.index
    it+=1
# Out:
# Solving problem 0 out of 23, for W = 0.0093 and N = 10 i = 1  j = 0
#
#
# Solving problem 1 out of 23, for W = 0.017599999999999998 and N = 70 i = 2  j = 15

# %%
#RECALCULATE SOLUTIONS NOT SOLVED BY PULP WITH GLPK, reversing indexes
zeroindexes = (entropies == 0).nonzero()
totzeros = len(zeroindexes[0])
zeroindexes = zip(zeroindexes[0], zeroindexes[1])

data.df.sort_index(by="p",inplace=True,ascending=False)
data.df.set_index(pd.Index([j for j in range(len(data.df))]), inplace=True)

def reverseindex(pdindex,totpatterns=512):
    newindex = []
    for i in pdindex:
        newindex.append(totpatterns -1 -i)
    return(pd.Index(newindex))
  
#function test
#a = [0,1,2,3]
#print(a,reverseindex(a))

it = 0
for i,j in zeroindexes:
    print("\n\nSolving problem {0} out of {1}, for W = {2} and N = {3} i = {4}  j = {5}".format(it, totzeros, Wrange[i], Nrange[j],i,j))
    glpsol = BPV.BPV("glpk",data,Nrange[j],Wrange[i],time_solver=True)
    glpsol.solve()
    entropies[i,j] = glpsol.solution_entropy
    rates[i,j] = glpsol.solution_rate
    cardinalities[i,j] = glpsol.solution_cardinality
    indexes[(i,j)] = glpsol.solution.index
    it+=1

    
data.df.sort_index(by="p",inplace=True,ascending=True)
data.df.set_index(pd.Index([j for j in range(len(data.df))]), inplace=True)
data.df
# Out:
# Solving problem 0 out of 23, for W = 0.0093 and N = 10 i = 1  j = 0
#
#
# Solving problem 1 out of 23, for W = 0.017599999999999998 and N = 70 i = 2  j = 15

# %%
#SAVE EXACT SOLUTIONS
f1 = open("/home/renato/tesi/code/data/plot6.entropies",r'wb')
f2 = open("/home/renato/tesi/code/data/plot6.rates",r'wb')
f3 = open("/home/renato/tesi/code/data/plot6.cardinalities",r'wb')
f4= open("/home/renato/tesi/code/data/plot6.indexes",r'wb')

pickle.dump(entropies,f1)
pickle.dump(rates,f2)
pickle.dump(cardinalities,f3)
pickle.dump(indexes,f4)

# %%
#LOAD EXACT SOLUTIONS
f1 = open("/home/renato/tesi/code/data/plot6.entropies",r'rb')
f2 = open("/home/renato/tesi/code/data/plot6.rates",r'rb')
f3 = open("/home/renato/tesi/code/data/plot6.cardinalities",r'rb')
f4 = open("/home/renato/tesi/code/data/plot6.indexes",r'rb')

entropies = pickle.load(f1)
rates = pickle.load(f2)
cardinalities = pickle.load(f3)
indexes = pickle.load(f4)

# %%
#REVERSE INDEXES, IF THEY WERE SAVED AS DECREASING FOR P 
def reverseindex(pdindex,totpatterns=512):
    newindex = []
    for i in pdindex:
        newindex.append(totpatterns -1 -i)
    return(pd.Index(newindex))
print(indexes[0,0])
for i,j in [(x,y) for x in range(Wnsteps) for y in range(Nnsteps)]:
    indexes[i,j] = reverseindex(indexes[i,j])
print(indexes[0,0])
# Out:
# Int64Index([257, 258, 262, 263, 265, 266, 267, 268, 269, 270], dtype='int64')
# Int64Index([254, 253, 249, 248, 246, 245, 244, 243, 242, 241], dtype='int64')

# %%
#CALCULATE HEURISTIC SOLUTIONS
heur_entropies = np.zeros((Wnsteps, Nnsteps))
heur_rates = np.zeros((Wnsteps, Nnsteps))
heur_cardinalities = np.zeros((Wnsteps, Nnsteps), dtype='int')
heur_indexes = {}

it = 1
for i,j in [(x,y) for x in range(Wnsteps) for y in range(Nnsteps)]:
    W = Wrange[i]
    N = Nrange[j]
    print("Solving problem {0} out of {1}, for W = {2} and N = {3}".format(it, nproblems, W, N))
    
    prbl_heur = BPV.BPV("heuristic",data,N,W,time_solver=False)
    prbl_heur.solve()
    
    heur_entropies[i,j] = prbl_heur.solution_entropy
    heur_rates[i,j] = prbl_heur.solution_rate
    heur_cardinalities[i,j] = prbl_heur.solution_cardinality
    heur_indexes[(i,j)] = prbl_heur.solution.index
    it += 1

# %%
#SAVE HEURISTIC SOLUTIONS
heur_f1 = open("/home/renato/tesi/code/data/plot6.heur_entropies",r'wb')
heur_f2 = open("/home/renato/tesi/code/data/plot6.heur_rates",r'wb')
heur_f3 = open("/home/renato/tesi/code/data/plot6.heur_cardinalities",r'wb')
heur_f4= open("/home/renato/tesi/code/data/plot6.heur_indexes",r'wb')

pickle.dump(heur_entropies,heur_f1)
pickle.dump(heur_rates,heur_f2)
pickle.dump(heur_cardinalities,heur_f3)
pickle.dump(heur_indexes,heur_f4)

# %%
#LOAD HEURISTIC SOLUTIONS
heur_f1 = open("/home/renato/tesi/code/data/plot6.heur_entropies",r'rb')
heur_f2 = open("/home/renato/tesi/code/data/plot6.heur_rates",r'rb')
heur_f3 = open("/home/renato/tesi/code/data/plot6.heur_cardinalities",r'rb')
heur_f4 = open("/home/renato/tesi/code/data/plot6.heur_indexes",r'rb')

heur_entropies = pickle.load(heur_f1)
heur_rates = pickle.load(heur_f2)
heur_cardinalities = pickle.load(heur_f3)
heur_indexes = pickle.load(heur_f4)

# %%
#REVERSE INDEXES, IF THEY WERE SAVED AS DECREASING FOR P 
def reverseindex(pdindex,totpatterns=512):
    newindex = []
    for i in pdindex:
        newindex.append(totpatterns -1 -i)
    return(pd.Index(newindex))
print(heur_indexes[0,0])
for i,j in [(x,y) for x in range(Wnsteps) for y in range(Nnsteps)]:
    heur_indexes[i,j] = reverseindex(heur_indexes[i,j])
print(heur_indexes[0,0])
# Out:
# Int64Index([265, 264, 263, 266, 262, 261, 260, 259, 258], dtype='int64')
# Int64Index([246, 247, 248, 245, 249, 250, 251, 252, 253], dtype='int64')

# %%
#RESCALE ENTROPIES (FOR HAVING THEM IN LOG 2)
entropies *= np.log2(np.e)
heur_entropies *= np.log2(np.e)

# %%
#ENTROPIES EX AND HEUR

fig = plt.figure(figsize=(20,10))
#ax = fig.gca(projection='3d')
X, Y = np.meshgrid(Wrange, Nrange)
elev = 22
azimuth = -135
#elev = 40
#azimuth = 47
al = 1
cb_shrink = 0.1
cb_aspect = 10
label_size = 16
title_size = 20
title_rotation = 'horizontal'
title_x = 0.4
title_y = 0
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
colormap = cm.gnuplot
_dpi = 80

#gs = gridspec.GridSpec(2,7, width_ratios=[1,0.1,10,0.1,10,0.1,10], height_ratios=[1,1])

gs = gridspec.GridSpec(2,4, width_ratios=[1,100,1,100],height_ratios=[1,10000])

title1 = plt.subplot(gs[0,:2])
title1.axis('off')
title1.text(title_x,title_y,"Exact",fontsize=title_size, rotation=title_rotation)

title2 = plt.subplot(gs[0,2:])
title2.axis('off')
title2.text(title_x,title_y,"Heuristic",fontsize=title_size, rotation=title_rotation)

cex_entropy = plt.subplot(gs[1,0])
ex_entropy = plt.subplot(gs[1,1], projection='3d') #exact entropy

cheur_entropy = plt.subplot(gs[1,2])
heur_entropy = plt.subplot(gs[1,3], projection='3d') #exact entropy

surf_e = ex_entropy.plot_surface(X, Y, entropies.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
ex_entropy.set_xlabel('W',fontsize=label_size)
ex_entropy.set_ylabel('N',fontsize=label_size)
ex_entropy.zaxis.set_rotate_label(False)  # disable automatic rotation
ex_entropy.set_zlabel('Entropy',rotation='vertical',fontsize=label_size, horizontalalignment='right')
ex_entropy.view_init(elev,azimuth)
plt.colorbar(surf_e, cax=cex_entropy)

surf_he = heur_entropy.plot_surface(X, Y, heur_entropies.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
heur_entropy.set_xlabel('W',fontsize=label_size)
heur_entropy.set_ylabel('N',fontsize=label_size)
heur_entropy.zaxis.set_rotate_label(False)  # disable automatic rotation
heur_entropy.set_zlabel('Entropy',rotation='vertical',fontsize=label_size, horizontalalignment='right')
heur_entropy.view_init(elev,azimuth)
plt.colorbar(surf_he, cax=cheur_entropy)

plt.savefig("/home/renato/tesi/testogit/img/NWentropies.pdf",  bbox_inches='tight')
plt.show()

# %%
#RATES EX AND HEUR

fig = plt.figure(figsize=(20,10))
#ax = fig.gca(projection='3d')
X, Y = np.meshgrid(Wrange, Nrange)
elev = 22
azimuth = -135
#elev = 40
#azimuth = 47
al = 1
cb_shrink = 0.1
cb_aspect = 10
label_size = 16
title_size = 20
title_rotation = 'horizontal'
title_x = 0.4
title_y = 0
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
colormap = cm.gnuplot
_dpi = 80

#gs = gridspec.GridSpec(2,7, width_ratios=[1,0.1,10,0.1,10,0.1,10], height_ratios=[1,1])

gs = gridspec.GridSpec(2,4, width_ratios=[1,100,1,100],height_ratios=[1,10000])

title1 = plt.subplot(gs[0,:2])
title1.axis('off')
title1.text(title_x,title_y,"Exact",fontsize=title_size, rotation=title_rotation)

title2 = plt.subplot(gs[0,2:])
title2.axis('off')
title2.text(title_x,title_y,"Heuristic",fontsize=title_size, rotation=title_rotation)

cex_entropy = plt.subplot(gs[1,0])
ex_entropy = plt.subplot(gs[1,1], projection='3d') #exact entropy

cheur_entropy = plt.subplot(gs[1,2])
heur_entropy = plt.subplot(gs[1,3], projection='3d') #exact entropy

surf_e = ex_entropy.plot_surface(X, Y, rates.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
ex_entropy.set_xlabel('W',fontsize=label_size)
ex_entropy.set_ylabel('N',fontsize=label_size)
ex_entropy.zaxis.set_rotate_label(False)  # disable automatic rotation
ex_entropy.set_zlabel('Entropy',rotation='vertical',fontsize=label_size, horizontalalignment='right')
ex_entropy.view_init(elev,azimuth)
plt.colorbar(surf_e, cax=cex_entropy)

surf_he = heur_entropy.plot_surface(X, Y, heur_rates.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
heur_entropy.set_xlabel('W',fontsize=label_size)
heur_entropy.set_ylabel('N',fontsize=label_size)
heur_entropy.zaxis.set_rotate_label(False)  # disable automatic rotation
heur_entropy.set_zlabel('Entropy',rotation='vertical',fontsize=label_size, horizontalalignment='right')
heur_entropy.view_init(elev,azimuth)
plt.colorbar(surf_he, cax=cheur_entropy)

#plt.savefig("/home/renato/tesi/testogit/img/NWsummaryExact.pdf",  bbox_inches='tight')
plt.show()

# %%
#CARDINALITIES EX AND HEUR

fig = plt.figure(figsize=(20,10))
#ax = fig.gca(projection='3d')
X, Y = np.meshgrid(Wrange, Nrange)
elev = 22
azimuth = -135
#elev = 40
#azimuth = 47
al = 1
cb_shrink = 0.1
cb_aspect = 10
label_size = 16
title_size = 20
title_rotation = 'horizontal'
title_x = 0.4
title_y = 0
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
colormap = cm.gnuplot
_dpi = 80

#gs = gridspec.GridSpec(2,7, width_ratios=[1,0.1,10,0.1,10,0.1,10], height_ratios=[1,1])

gs = gridspec.GridSpec(2,4, width_ratios=[1,100,1,100],height_ratios=[1,10000])

title1 = plt.subplot(gs[0,:2])
title1.axis('off')
title1.text(title_x,title_y,"Exact",fontsize=title_size, rotation=title_rotation)

title2 = plt.subplot(gs[0,2:])
title2.axis('off')
title2.text(title_x,title_y,"Heuristic",fontsize=title_size, rotation=title_rotation)

cex_entropy = plt.subplot(gs[1,0])
ex_entropy = plt.subplot(gs[1,1], projection='3d') #exact entropy

cheur_entropy = plt.subplot(gs[1,2])
heur_entropy = plt.subplot(gs[1,3], projection='3d') #exact entropy

surf_e = ex_entropy.plot_surface(X, Y, cardinalities.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
ex_entropy.set_xlabel('W',fontsize=label_size)
ex_entropy.set_ylabel('N',fontsize=label_size)
ex_entropy.zaxis.set_rotate_label(False)  # disable automatic rotation
ex_entropy.set_zlabel('Entropy',rotation='vertical',fontsize=label_size, horizontalalignment='right')
ex_entropy.view_init(elev,azimuth)
plt.colorbar(surf_e, cax=cex_entropy)

surf_he = heur_entropy.plot_surface(X, Y, heur_cardinalities.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
heur_entropy.set_xlabel('W',fontsize=label_size)
heur_entropy.set_ylabel('N',fontsize=label_size)
heur_entropy.zaxis.set_rotate_label(False)  # disable automatic rotation
heur_entropy.set_zlabel('Entropy',rotation='vertical',fontsize=label_size, horizontalalignment='right')
heur_entropy.view_init(elev,azimuth)
plt.colorbar(surf_he, cax=cheur_entropy)

#plt.savefig("/home/renato/tesi/testogit/img/NWsummaryExact.pdf",  bbox_inches='tight')
plt.show()

# %%
# EXACT AND HEUR MEGA PLOT A
fig = plt.figure(figsize=(9,25))
#ax = fig.gca(projection='3d')
X, Y = np.meshgrid(Wrange, Nrange)
elev = 22
azimuth = -135
#elev = 40
#azimuth = 47
al = 1
cb_shrink = 0.1
cb_aspect = 10
label_size = 16
title_size = 20
title_rotation = 'horizontal'
title_x = 0.4
title_y = 0
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
colormap = cm.gnuplot
_dpi = 80

#gs = gridspec.GridSpec(2,7, width_ratios=[1,0.1,10,0.1,10,0.1,10], height_ratios=[1,1])

gs = gridspec.GridSpec(4,2, width_ratios=[1,100], height_ratios=[1,10,10,10])

title1 = plt.subplot(gs[0,:2])
cex_entropy = plt.subplot(gs[1,0])
ex_entropy = plt.subplot(gs[1,1], projection='3d') #exact entropy

cex_rate = plt.subplot(gs[2,0])
ex_rate = plt.subplot(gs[2,1], projection='3d') #exact rate

cex_card = plt.subplot(gs[3,0])
ex_card = plt.subplot(gs[3,1], projection='3d') #exact cardinality

title1.axis('off')
title1.text(title_x,title_y,"Exact Solution",fontsize=title_size, rotation=title_rotation)

surf_e = ex_entropy.plot_surface(X, Y, entropies.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
ex_entropy.set_xlabel('W',fontsize=label_size)
ex_entropy.set_ylabel('N',fontsize=label_size)
ex_entropy.zaxis.set_rotate_label(False)  # disable automatic rotation
ex_entropy.set_zlabel('Entropy',rotation='vertical',fontsize=label_size, horizontalalignment='right')
ex_entropy.view_init(elev,azimuth)
plt.colorbar(surf_e, cax=cex_entropy)



surf_r = ex_rate.plot_surface(X, Y, rates.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
ex_rate.set_xlabel('W',fontsize=label_size)
ex_rate.set_ylabel('N',fontsize=label_size)
ex_rate.zaxis.set_rotate_label(False)  # disable automatic rotation
ex_rate.set_zlabel('Rate',rotation='vertical',fontsize=label_size, horizontalalignment='right')
ex_rate.view_init(elev,azimuth)
plt.colorbar(surf_r, cax=cex_rate)

surf_c = ex_card.plot_surface(X, Y, cardinalities.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
ex_card.set_xlabel('W',fontsize=label_size)
ex_card.set_ylabel('N',fontsize=label_size)
ex_card.zaxis.set_rotate_label(False)  # disable automatic rotation
ex_card.set_zlabel('Cardinality',rotation='vertical',fontsize=label_size, horizontalalignment='right',)
ex_card.view_init(elev,azimuth)
plt.colorbar(surf_c, cax=cex_card)

fig.tight_layout()
#plt.savefig("/home/renato/tesi/testogit/img/NWsummaryExact.pdf",  bbox_inches='tight')
plt.show()

# %%
# EXACT AND HEUR MEGA PLOT  B
fig = plt.figure(figsize=(9,25))
#ax = fig.gca(projection='3d')
X, Y = np.meshgrid(Wrange, Nrange)
elev = 22
azimuth = -135
#elev = 40
#azimuth = 47
al = 1
cb_shrink = 0.1
cb_aspect = 10
label_size = 16
title_size = 20
title_rotation = 'horizontal'
title_x = 0.4
title_y = 0
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
colormap = cm.gnuplot
_dpi = 80

#gs = gridspec.GridSpec(2,7, width_ratios=[1,0.1,10,0.1,10,0.1,10], height_ratios=[1,1])

gs = gridspec.GridSpec(4,2, width_ratios=[1,100], height_ratios=[1,10,10,10])

title2 = plt.subplot(gs[0,:])
cheur_entropy = plt.subplot(gs[1,0])
heur_entropy = plt.subplot(gs[1,1], projection='3d') #heur entropy

cheur_rate = plt.subplot(gs[2,0])
heur_rate = plt.subplot(gs[2,1], projection='3d') #heur rate

cheur_card = plt.subplot(gs[3,0])
heur_card = plt.subplot(gs[3,1], projection='3d') #heur cardinality




title2.axis('off')
title2.text(title_x,title_y,"Heuristic Solution",fontsize=title_size, rotation=title_rotation)

surf_he = heur_entropy.plot_surface(X, Y, heur_entropies.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
heur_entropy.set_xlabel('W',fontsize=label_size)
heur_entropy.set_ylabel('N',fontsize=label_size)
heur_entropy.zaxis.set_rotate_label(False)  # disable automatic rotation
heur_entropy.set_zlabel('Entropy',rotation='vertical',fontsize=label_size, horizontalalignment='right')
heur_entropy.view_init(elev,azimuth)
plt.colorbar(surf_he, cax=cheur_entropy)



surf_hr = heur_rate.plot_surface(X, Y, heur_rates.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
heur_rate.set_xlabel('W',fontsize=label_size)
heur_rate.set_ylabel('N',fontsize=label_size)
heur_rate.zaxis.set_rotate_label(False)  # disable automatic rotation
heur_rate.set_zlabel('Rate',rotation='vertical',fontsize=label_size, horizontalalignment='right')
heur_rate.view_init(elev,azimuth)
plt.colorbar(surf_hr, cax=cheur_rate)


surf_hc = heur_card.plot_surface(X, Y, heur_cardinalities.T, rstride=1, cstride=1, alpha=al, cmap=colormap)
heur_card.set_xlabel('W',fontsize=label_size)
heur_card.set_ylabel('N',fontsize=label_size)
heur_card.zaxis.set_rotate_label(False)  # disable automatic rotation
heur_card.set_zlabel('Cardinality',rotation='vertical',fontsize=label_size, horizontalalignment='right')
heur_card.view_init(elev,azimuth)
plt.colorbar(surf_hc, cax=cheur_card)

fig.tight_layout()
#plt.savefig("/home/renato/tesi/testogit/img/NWsummaryHeur.pdf",  bbox_inches='tight')
plt.show()

# %%
#CALCULATE GRADIENT, NOT INTERVAL MEASURE, RELATIVE ERROR
ax = fig.gca(projection='3d')
X, Y = np.meshgrid(Wrange, Nrange)
gx, gy = np.gradient(entropies)
grad = np.zeros((Wnsteps, Nnsteps))
not_interval_measure =  np.zeros((Wnsteps, Nnsteps))
relerr = np.zeros((Wnsteps,Nnsteps))
for i,j in [(x,y) for x in range(Wnsteps) for y in range(Nnsteps)]:
    grad[i,j] = np.sqrt(gx[i,j]**2 + gy[i,j]**2)
    not_interval_measure[i,j] = BPV.not_interval_measure(indexes[i,j])
    relerr[i,j] = (entropies[i,j] - heur_entropies[i,j])/entropies[i,j]

# %%
#RELATIVE ERRROR
matplotlib.style.use('ggplot')

fig = plt.figure(figsize=(10,5))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

X, Y = np.meshgrid(Wrange, Nrange)
elev = 35
azimuth = 31
al = 0.6
cb_shrink = 0.5
cb_aspect = 10
label_size = 16
#gradoffset = 5*relerr.min()
gradoffset = 0
gradlinew = 3
gradcolor = 'k'
ncountourlines = 7
ext3d = False
colormap = cm.gnuplot

mingr = grad.min()
maxgr = grad.max()
grcontourlevels = list(np.arange(mingr,maxgr,(maxgr-mingr)/ncountourlines ))

relmin = relerr.min()
relmax = relerr.max()
ax = fig.add_subplot(1, 1, 1, projection='3d')
surf_e = ax.plot_surface(X, Y, relerr.T, rstride=1, cstride=1, alpha=al, \
                         vmin=relmin, vmax=relmax/2, cmap=colormap)
cset = ax.contour(X, Y, grad.T, zdir='z', offset=gradoffset, colors=gradcolor, \
                  levels=grcontourlevels, linewidths=gradlinew, extend3d=ext3d)
ax.set_xlabel('W')
ax.set_ylabel('N')
ax.zaxis.set_rotate_label(False)  # disable automatic rotation
ax.set_zlabel('Relative Error',rotation='vertical',fontsize=label_size, horizontalalignment='right')
ax.view_init(elev,azimuth)
fig.colorbar(surf_e, shrink=cb_shrink, aspect=cb_aspect)

plt.savefig("/home/renato/tesi/testogit/img/NWrelerr.pdf",  bbox_inches='tight')
plt.show()

# %%
#NOT INTERVAL MEASURE
matplotlib.style.use('ggplot')

fig = plt.figure(figsize=(10,5))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

X, Y = np.meshgrid(Wrange, Nrange)
elev = 35
azimuth = 31
al = 0.65
cb_shrink = 0.5
cb_aspect = 10
label_size = 16
gradoffset = 5*relerr.min()
gradlinew = 3
gradcolor = 'k'
ncountourlines = 7
ext3d = False
colormap = cm.gnuplot

mingr = grad.min()
maxgr = grad.max()
grcontourlevels = list(np.arange(mingr,maxgr,(maxgr-mingr)/ncountourlines ))

nimin = not_interval_measure.min()
nimax = not_interval_measure.max()
ax = fig.add_subplot(1, 1, 1, projection='3d')
surf_r = ax.plot_surface(X, Y, not_interval_measure.T, rstride=1, cstride=1, alpha=al,\
                         vmin=nimin,vmax=nimax, cmap=colormap)
cset = ax.contour(X, Y, grad.T, zdir='z', offset=gradoffset, colors=gradcolor, \
                  levels=grcontourlevels, linewidths=gradlinew, extend3d=ext3d)
ax.set_xlabel('W')
ax.set_ylabel('N')
ax.zaxis.set_rotate_label(False)  # disable automatic rotation
ax.set_zlabel('$\mathcal{I}(S)$',rotation='vertical',fontsize=label_size, horizontalalignment='right')
ax.view_init(elev,azimuth)
fig.colorbar(surf_r, shrink=cb_shrink, aspect=cb_aspect)

#plt.savefig("/home/renato/tesi/testogit/img/NWnimeasure.pdf",  bbox_inches='tight')
plt.show()

# %%
#MEAN VALUES OF INDEXES 1
heur_solmean = np.zeros((Wnsteps,Nnsteps))
ex_solmean = np.zeros((Wnsteps,Nnsteps))

for i,j in [(x,y) for x in range(Wnsteps) for y in range(Nnsteps)]:
    hm = (np.array(heur_indexes[i,j])).mean()
    if math.isnan(hm):
        print(i,j, heur_indexes[i,j])
    heur_solmean[i,j] = hm
    ex_solmean[i,j] = (np.array(indexes[i,j])).mean()
    
fig = plt.figure(figsize=(10,10))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

hmin = 1000
hmax = -2000
for coords,d in np.ndenumerate(heur_solmean):
    if math.isnan(d) == False:
        if d < hmin:
            hmin=d
        elif d> hmax:
            hmax=d
hmin *= 1
hmax *= 1

emin = 1000
emax = -2000
for coords,d in np.ndenumerate(ex_solmean):
    if math.isnan(d) == False:
        if d < emin:
            emin=d
        elif d> emax:
            emax=d
emin *= 1
emax *= 1

X, Y = np.meshgrid(Wrange, Nrange)
elev = 15
azimuth = 124
al = 0.7
cb_shrink = 0.5
cb_aspect = 10
label_size = 16
gradoffset = 0
gradlinew = 0.2
ncountourlines = 10
colormap = cm.gnuplot

ax = fig.add_subplot(2, 1, 1, projection='3d')
surf_e = ax.plot_surface(X, Y, ex_solmean.T, rstride=1, cstride=1, alpha=al, cmap=colormap,\
                        vmin=emin,vmax=emax)
ax.set_title('Exact Solution')
ax.set_xlabel('W')
ax.set_ylabel('N')
ax.zaxis.set_rotate_label(False)  # disable automatic rotation
ax.set_zlabel('$m(S_{\\text{ex}})$',rotation='vertical',fontsize=label_size, horizontalalignment='right')
ax.view_init(elev,azimuth)
fig.colorbar(surf_e, shrink=cb_shrink, aspect=cb_aspect)


grcontourlevels = list(np.arange(hmin,hmax,(hmax-hmin)/ncountourlines ))

ax = fig.add_subplot(2, 1, 2, projection='3d')
surf_r = ax.plot_surface(X, Y, heur_solmean.T, rstride=1, cstride=1, alpha=al, cmap=colormap,\
                        vmin=hmin,vmax=hmax)
#cset = ax.contour(X, Y, heur_solmean.T, zdir='y', offset=gradoffset, colors=gradcolor, \
#                  levels=grcontourlevels, linewidths=gradlinew, extend3d=ext3d)
ax.set_title('Heuristic Solution')
ax.set_xlabel('W')
ax.set_ylabel('N')
ax.zaxis.set_rotate_label(False)  # disable automatic rotation
ax.set_zlabel('$m(S_{\\text{heur}})$',rotation='vertical',fontsize=label_size, horizontalalignment='right')
ax.view_init(elev,azimuth)
fig.colorbar(surf_r, shrink=cb_shrink, aspect=cb_aspect)

#plt.savefig("/home/renato/tesi/testogit/img/NWmediumindexes.pdf",  bbox_inches='tight')

plt.show()

# %%
#DIFF OF MEAN INDEXES
heur_solmean = np.zeros((Wnsteps,Nnsteps))
ex_solmean = np.zeros((Wnsteps,Nnsteps))

for i,j in [(x,y) for x in range(Wnsteps) for y in range(Nnsteps)]:
    hm = (np.array(heur_indexes[i,j])).mean()
    if math.isnan(hm):
        print(i,j, heur_indexes[i,j])
    heur_solmean[i,j] = hm
    ex_solmean[i,j] = (np.array(indexes[i,j])).mean()
    
#fig = plt.figure(figsize=(10,10))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

X, Y = np.meshgrid(Wrange, Nrange)
elev = 24
azimuth = -66
al = 1
cb_shrink = 0.5
cb_aspect = 10
label_size = 16
gradoffset = 0
gradlinew = 2
ncountourlines = 10
colormap = cm.gnuplot

fig = plt.figure()
ax = fig.gca(projection='3d')
#diff = ex_solmean.T - heur_solmean.T
diff = heur_solmean.T - ex_solmean.T
dmin = 10
dmax = -20
for coords,d in np.ndenumerate(diff):
    if math.isnan(d) == False:
        if d < dmin:
            dmin=d
        elif d> dmax:
            dmax=d

surf_e = ax.plot_surface(X, Y, diff, rstride=1, cstride=1, alpha=al, cmap=colormap,\
                        vmin=dmin, vmax=dmax)
ax.set_xlabel('W')
ax.set_ylabel('N')
ax.zaxis.set_rotate_label(False)  # disable automatic rotation
ax.set_zlabel('$m(S_{\\text{heur}}) - m(S_{\\text{ex}})$',rotation='vertical',fontsize=label_size, horizontalalignment='right')
ax.view_init(elev,azimuth)
fig.colorbar(surf_e, shrink=cb_shrink, aspect=cb_aspect)
#plt.savefig("/home/renato/tesi/testo/img/NWdiffmediumindex.pdf",  bbox_inches='tight')
#plt.savefig("/home/renato/tesi/testogit/img/NWdiffmediumindex.pdf")

plt.show()

# %%
#PULP TIMES
matplotlib.style.use('ggplot')

fig = plt.figure(figsize=(10,5))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

X, Y = np.meshgrid(Wrange, Nrange)
elev = 35
azimuth = 31
al = 0.65
cb_shrink = 0.5
cb_aspect = 10
label_size = 16
gradoffset = times.min()
gradlinew = 3
gradcolor = 'k'
ncountourlines = 7
zmax = 0.4
ext3d = False
colormap = cm.gnuplot

mingr = grad.min()
maxgr = grad.max()
grcontourlevels = list(np.arange(mingr,maxgr,(maxgr-mingr)/ncountourlines ))

tmin = times.min()
tmax = times.max()
ax = fig.add_subplot(1, 1, 1, projection='3d')
surf_r = ax.plot_surface(X, Y, times.T, rstride=1, cstride=1, alpha=al,\
                         vmin=times.min(),vmax=zmax, cmap=colormap)
cset = ax.contour(X, Y, grad.T, zdir='z', offset=gradoffset, colors=gradcolor, \
                  levels=grcontourlevels, linewidths=gradlinew, extend3d=ext3d)
ax.set_xlabel('W')
ax.set_ylabel('N')
ax.set_zlim(0,0.5)
ax.zaxis.set_rotate_label(False)  # disable automatic rotation
ax.set_zlabel('seconds',rotation='vertical',fontsize=label_size, horizontalalignment='right')
ax.view_init(elev,azimuth)
fig.colorbar(surf_r, shrink=cb_shrink, aspect=cb_aspect)

#plt.savefig("/home/renato/tesi/testogit/img/NWtimes.pdf",  bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f552d2db3689> in <module>()
#      13 cb_aspect = 10
#      14 label_size = 16
# ---> 15 gradoffset = times.min()
#      16 gradlinew = 3
#      17 gradcolor = 'k'
#
# NameError: name 'times' is not defined

# %%
times
# Out:
# array([[  0.29845797,   0.14410875,   0.18421533,   0.1794002 ,
#           0.27965561,   0.14484194,   0.19902669,   0.17123234,
#           0.1364557 ,   0.16303439,   0.13594837,   0.14827694,
#           0.15935585,   0.18847369,   0.19393904,   0.19392332,
#           0.19329098,   0.19078941,   0.19021517,   0.1884725 ,
#           0.18634751,   0.18622738,   0.18776808,   0.18858676,
#           0.19091554,   0.20689262,   0.20329699,   0.20640492,
#           0.189959  ,   0.20818349],
#        [  0.1974964 ,   0.17502053,   0.23769195,   0.20096813,
#           0.24896523,   0.2202429 ,   0.16808739,   0.19211716,
#           0.27103525,   0.19276452,   0.20440865,   0.26146303,
#           0.16615335,   0.19527489,   0.1620631 ,   0.21724022,
#           0.15721005,   0.16161388,   0.14881849,   0.15204229,
#           0.18101164,   0.15456174,   0.18507954,   0.16428643,
#           0.1704562 ,   0.20289149,   0.21377267,   0.22927336,
#           0.19164727,   0.15361567],
#        [  0.16498365,   0.22471204,   0.1983391 ,   0.28748515,
#           0.27120063,   0.20897165,   0.27092155,   0.18292948,
#           0.30213999,   0.19290748,   0.20091051,   0.19375081,
#           0.19788422,   0.19389413,   0.20310925,   0.26686943,
#           0.19508457,   0.22610048,   0.17886673,   0.20651779,
#           0.21253691,   0.24268528,   0.21974584,   0.18559201,
#           0.18926697,   0.22796103,   0.18136166,   0.14986571,
#           0.17515579,   0.22515356],
#        [  0.26929013,   0.20143357,   0.1918988 ,   0.18727706,
#           0.17824116,   0.31666096,   0.36710425,   0.18455158,
#           0.27804869,   0.18862409,   0.2485168 ,   0.24814609,
#           0.2390314 ,   0.21299178,   0.26288563,   0.27845754,
#           0.26274888,   0.21853102,   0.18058035,   0.22848994,
#           0.2108691 ,   0.22871797,   0.18020293,   0.21603881,
#           0.16753955,   0.19576303,   0.17178191,   0.25327116,
#           0.25915758,   0.19766704],
#        [  0.16415757,   0.2964287 ,   0.30207179,   0.36861421,
#           0.20131596,   0.18629978,   0.2219943 ,   0.19564053,
#           0.22458359,   0.1734604 ,   0.22589108,   0.18563915,
#           0.21695799,   0.53850517,   1.85723552,   0.18731764,
#           0.2669047 ,   0.21169421,   0.19603122,   0.21850434,
#           0.19481438,   0.27231473,   0.35944638,   0.34866082,
#           0.27409296,   0.21085981,   0.16684847,   0.19069788,
#           0.27548035,   0.52174499],
#        [  0.13743979,   0.19313827,   0.2587546 ,   0.25480194,
#           0.43638821,   0.16950858,   0.31496291,   0.36404549,
#           0.27703508,   0.21903555,   0.19692603,   0.16484872,
#           0.27126076,   0.22643529,   0.23554766,   0.26265243,
#           0.22844929,   7.96938593,   0.24911059,   0.20746519,
#           0.20966763,   0.25541773,   0.22571257,   0.22238422,
#           0.18789606,   0.19295102,   0.23436902,   0.24854236,
#           0.2430838 ,   0.24451435],
#        [  0.13887572,   0.16240316,   0.22089947,   0.22789608,
#           0.2266328 ,   0.15147631,   0.18820518,   0.19048277,
#           0.21058157,   0.22023333,   0.33239909,   0.25355982,
#           0.148533  ,   0.19039561,   0.57194718,   0.23250811,
#           0.2057867 ,   0.19650126,   0.38959853,   0.22190085,
#           0.19613375,   0.25790764,   0.24585244,   0.20175533,
#           0.20597136,   0.30435322,   0.2590612 ,   0.22932342,
#           0.24913301,   0.20695367],
#        [  0.14061497,   0.14030802,   0.15512795,   0.24557985,
#           2.93605679,   0.1733342 ,   0.25189229,   0.19956532,
#           0.28186718,   0.17341647,   0.21273561,   0.16402047,
#           0.34839096,   0.23427236,   0.26466595,   0.24533114,
#           0.19497676,   0.20174206,   0.27993098,   0.28987076,
#           0.76003643,   0.22820555,   0.28664159,   0.27469674,
#           0.24353085,   0.2063881 ,   0.18375449,   0.1829305 ,
#           0.23644708,   0.19037703],
#        [  0.13688812,   0.13858749,   0.13974538,   0.19587869,
#           0.1800372 ,   0.44387064,   0.14689816,   0.18189169,
#           0.2027021 ,   0.25460506,   0.23135901,   0.20400233,
#           0.18325471,   0.18080391,   0.22937699,   0.33990785,
#           0.31495286,   0.23576633,   0.2458627 ,   0.19762088,
#           0.21411839,   0.20596521,   0.82204156,   0.19079726,
#           0.26675413,   0.29240417,   0.20618828,   0.26685072,
#           0.24140496,   0.38532076],
#        [  0.13599101,   0.13865237,   0.13967938,   0.13664751,
#           0.29937648,   0.19179927,   0.17685021,   0.27606848,
#           0.18228266,   0.23884542,   0.23217595,   0.24321964,
#           0.23658264,   0.21161137,   0.32526385,   0.36851588,
#           0.19710503,   0.29781504,   0.20025766,   0.22308368,
#           0.27276032,   0.24411221,   0.32382184,   0.20074899,
#           2.24154493,   0.21997387,   0.36860115,   0.30097794,
#           0.24620632,   0.81025036],
#        [  0.14033219,   0.13933772,   0.14038275,   0.1399459 ,
#           0.14065898,   0.13640775,   0.19105617,   0.18713612,
#           0.2600137 ,   0.20920074,   0.26239584,   0.18427159,
#           0.17969295,   0.24219053,   0.20153952,   0.29869295,
#           0.18731324,   0.18240097,   0.2082671 ,   0.19756424,
#           0.25401323,   0.17682074,   0.23648214,   0.23032383,
#           0.21139906,   0.22630098,   0.45081187,   0.24307206,
#           0.20929635,   0.19586598],
#        [  0.13659925,   0.13568825,   0.13794139,   0.13523805,
#           0.13589637,   0.13554193,   0.1372397 ,   0.30312024,
#           0.18923387,   0.16383937,   0.18224327,   0.17209696,
#           0.22909169,   0.17246649,   0.24513133,   0.14661824,
#           0.22783895,   0.23848322,   0.18693673,   0.23479485,
#           0.16659118,   0.207285  ,   0.17849944,   0.20520073,
#           0.25640137,   0.18982976,   0.25490496,   0.28629608,
#           0.18726191,   0.2215879 ],
#        [  0.13805244,   0.13879471,   0.14773011,   0.13985503,
#           0.1415556 ,   0.13933451,   0.14085111,   0.14301821,
#           0.16466042,   0.1577963 ,   0.17871944,   0.1828117 ,
#           1.01727541,   0.18939458,   0.18580363,   0.21194277,
#           0.27902751,   0.22271806,   0.15843877,   0.23900878,
#           0.28245881,   0.21659719,   0.21097666,   0.17718824,
#           0.22723127,   0.92068016,   0.25945776,   0.2701834 ,
#           0.28822761,   0.23652851],
#        [  0.13534442,   0.13504012,   0.13837734,   0.13563922,
#           0.13822075,   0.13872466,   0.13964425,   0.14048661,
#           0.1408655 ,   0.14093052,   0.1383436 ,   0.1814072 ,
#           0.96721821,   0.18075111,   0.1645396 ,   0.1705078 ,
#           0.22285321,   0.21753739,   0.21968668,   0.18587961,
#           0.29243917,   0.4066855 ,   0.18497657,   0.2466804 ,
#           0.22698459,   0.45140992,   0.22218951,   0.22967151,
#           0.31882506,   0.23488515],
#        [  0.13975956,   0.14053969,   0.13859399,   0.13926697,
#           0.13909921,   0.13923953,   0.13879401,   0.1371496 ,
#           0.13920712,   0.13784256,   0.13669151,   0.13828082,
#           0.14073007,   0.23143172,   0.18768005,  10.52385801,
#           0.18024141,   0.27306378,   0.18817564,   0.24645258,
#           0.25171162,   0.76384641,   0.24932033,   0.21955978,
#           0.29363715,   0.2398848 ,   0.75228666,   0.22551792,
#           0.26714231,   0.23019993],
#        [  0.13692723,   0.14920292,   0.13791045,   0.13792833,
#           0.13825819,   0.14089986,   0.13883012,   0.13879568,
#           0.13830317,   0.13939527,   0.13879464,   0.14137017,
#           0.13721672,   0.13740676,   0.13884911,   0.13639804,
#           0.18216651,   0.18816454,   0.15057138,   0.2459711 ,
#          27.48752298,   0.37371325,   0.26270419,   0.22580406,
#           0.31718589,   0.1862518 ,   0.16321192,   0.24985077,
#           0.34036021,   0.28621172],
#        [  0.13746675,   0.1373168 ,   0.13980161,   0.13786554,
#           0.13721427,   0.13827034,   0.13743532,   0.14121002,
#           0.13604877,   0.13837189,   0.13647745,   0.14002824,
#           0.13893132,   0.13890876,   0.1394179 ,   0.13946567,
#           0.13926446,   0.13709771,   0.1371577 ,   0.13778851,
#           0.14280128,   0.17675299,   0.19127058,   0.18378264,
#           0.17375925,   0.18555772,   0.16863348,   0.18985162,
#           3.59299637,   0.22837778],
#        [  0.13943829,   0.13819799,   0.139734  ,   0.13807926,
#           0.1394047 ,   0.13973016,   0.13856989,   0.13934988,
#           0.13771566,   0.13848594,   0.13763535,   0.13843705,
#           0.13751522,   0.13793008,   0.13703681,   0.13602837,
#           0.13738462,   0.13897155,   0.13855194,   0.14072169,
#           0.14358259,   0.14022324,   0.14540217,   0.1399811 ,
#           0.1375236 ,   0.13812954,   0.13723781,   0.13687603,
#           0.13721588,   0.18557364],
#        [  0.13795298,   0.13948467,   0.13998285,   0.14044952,
#           0.13838649,   0.14062622,   0.14679228,   0.13986426,
#           0.14068223,   0.13972618,   0.13880986,   0.13958936,
#           0.14241206,   0.14075578,   0.14142974,   0.14188511,
#           0.14192827,   0.13957274,   0.13743602,   0.13855941,
#           0.13666986,   0.13790996,   0.13639951,   0.14241834,
#           0.1424467 ,   0.1437551 ,   0.1415352 ,   0.14131912,
#           0.14171113,   0.14057978],
#        [  0.14080027,   0.13849991,   0.13834584,   0.13774416,
#           0.13669927,   0.13645112,   0.13870364,   0.13825204,
#           0.13951777,   0.14038241,   0.13890939,   0.13909852,
#           0.1378932 ,   0.1366737 ,   0.13767264,   0.13760043,
#           0.1373365 ,   0.13990756,   0.14349976,   0.1430546 ,
#           0.14209261,   0.14523392,   0.14579041,   0.14812415,
#           0.14783592,   0.14061491,   0.13990211,   0.13795836,
#           0.14245948,   0.13915292],
#        [  0.14209128,   0.13813052,   0.13964775,   0.13731121,
#           0.13772991,   0.1390284 ,   0.1393591 ,   0.13899641,
#           0.14016108,   0.14036585,   0.13757912,   0.13962714,
#           0.13999067,   0.14017665,   0.13908818,   0.13981921,
#           0.14233412,   0.13768801,   0.13716853,   0.13700049,
#           0.14331378,   0.14083987,   0.13831867,   0.13997859,
#           0.13908972,   0.14131136,   0.1393012 ,   0.15034405,
#           0.1415454 ,   0.1415292 ],
#        [  0.18211784,   0.18358191,   0.18601602,   0.18050276,
#           0.18117247,   0.18161875,   0.18119768,   0.18287009,
#           0.18261964,   0.18347841,   0.18065529,   0.18106477,
#           0.18066423,   0.18043355,   0.17987056,   0.17970147,
#           0.18187046,   0.18229446,   0.18147174,   0.18562239,
#           0.1829611 ,   0.18373759,   0.18378229,   0.18498837,
#           0.18503335,   0.19028107,   0.18323648,   0.1836396 ,
#           0.18413338,   0.18689434],
#        [  0.17955837,   0.18560752,   0.1801935 ,   0.18480022,
#           0.18479966,   0.19086529,   0.18101595,   0.18179042,
#           0.18148738,   0.18422899,   0.21454561,   0.18232834,
#           0.18171946,   0.18425015,   0.19029783,   0.17815757,
#           0.17914212,   0.18211148,   0.18217154,   0.18231597,
#           0.18166352,   0.18189553,   0.18562665,   0.18299015,
#           0.18169795,   0.18409874,   0.18325136,   0.18263836,
#           0.18440359,   0.18138723],
#        [  0.1819234 ,   0.18196335,   0.17970099,   0.1793918 ,
#           0.1793089 ,   0.17873334,   0.18002756,   0.18247836,
#           0.1804126 ,   0.17955474,   0.18015816,   0.18101693,
#           0.18037328,   0.17882839,   0.17975434,   0.1833205 ,
#           0.18092956,   0.17994529,   0.18066982,   0.18336813,
#           0.1844939 ,   0.18086216,   0.18142913,   0.18147432,
#           0.18196258,   0.18258109,   0.18460984,   0.18257893,
#           0.1807903 ,   0.18185432],
#        [  0.18000738,   0.18053447,   0.17981001,   0.18022808,
#           0.18004663,   0.17969198,   0.18121514,   0.18141063,
#           0.18139945,   0.18333251,   0.18162322,   0.18017849,
#           0.18330297,   0.18255232,   0.18275011,   0.18273516,
#           0.17984528,   0.18371412,   0.18175662,   0.18020943,
#           0.18212852,   0.1798758 ,   0.180159  ,   0.18106254,
#           0.18345006,   0.18385408,   0.18463365,   0.18202613,
#           0.18215534,   0.1825021 ],
#        [  0.1805249 ,   0.18385353,   0.18059488,   0.17980044,
#           0.18491993,   0.17967305,   0.17979129,   0.18196747,
#           0.18120592,   0.18144457,   0.18086915,   0.18058056,
#           0.18185705,   0.1807178 ,   0.18135671,   0.18261531,
#           0.18109718,   0.18133904,   0.18196069,   0.18295279,
#           0.18274871,   0.1826063 ,   0.18231185,   0.18432942,
#           0.18485233,   0.18345327,   0.18276603,   0.1829113 ,
#           0.18210617,   0.18453092],
#        [  0.18340619,   0.18503705,   0.18392861,   0.18223203,
#           0.18618608,   0.18282023,   0.18918932,   0.18328202,
#           0.18262111,   0.18199799,   0.18263396,   0.18463679,
#           0.18778069,   0.18401297,   0.18242521,   0.18502923,
#           0.18424233,   0.18181068,   0.18310001,   0.18006346,
#           0.18245147,   0.18240684,   0.17989612,   0.18176926,
#           0.18113713,   0.18224048,   0.18312543,   0.18207062,
#           0.18294147,   0.18268935],
#        [  0.17954817,   0.18036818,   0.18055989,   0.18051575,
#           0.17999215,   0.17947023,   0.18111904,   0.18156274,
#           0.18124301,   0.18178707,   0.18309833,   0.18065557,
#           0.18161107,   0.18246111,   0.18152475,   0.18049675,
#           0.18049969,   0.18019295,   0.18655198,   0.18194128,
#           0.1817745 ,   0.18212342,   0.18505752,   0.18273279,
#           0.18540009,   0.18251013,   0.18318424,   0.18350935,
#           0.18154144,   0.18151036],
#        [  0.17894139,   0.18020021,   0.18036713,   0.18033382,
#           0.18151643,   0.18090742,   0.18197515,   0.18151315,
#           0.18256224,   0.17964078,   0.18330325,   0.17938572,
#           0.18303499,   0.18596727,   0.18012248,   0.18284027,
#           0.1820994 ,   0.18165011,   0.18126305,   0.18148172,
#           0.18371496,   0.18068903,   0.18479359,   0.17995716,
#           0.18206818,   0.18261378,   0.1819373 ,   0.18317691,
#           0.182277  ,   0.18348023],
#        [  0.18113887,   0.18108747,   0.18283671,   0.18338461,
#           0.18380834,   0.18246383,   0.1827147 ,   0.18039381,
#           0.18079959,   0.17943685,   0.18096958,   0.18090972,
#           0.17924038,   0.18126172,   0.18194666,   0.18065299,
#           0.18038145,   0.17996561,   0.18131767,   0.18992824,
#           0.18482257,   0.18917765,   0.18504746,   0.18750293,
#           0.1862071 ,   0.18300405,   0.18688149,   0.18555723,
#           0.18273872,   0.18320436]])
