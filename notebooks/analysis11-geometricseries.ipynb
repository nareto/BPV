# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib
matplotlib.use('TkAgg')
#%matplotlib inline
import BPV
import pattern_manipulation as pm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import rcParams
import pickle
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import math
import gc


data = BPV.Data()
data.read_csv("pixel.dist.csv",False)
data = data.data_head(100)
data.order_by_p()
data.df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#    pattern-id         p  plog1onp
# 0       11000  0.000326  0.002616
# 1      110000  0.000328  0.002629
# 2   100000001  0.000342  0.002729
# 3   111000111  0.000342  0.002732
# 4    10010000  0.000350  0.002783
# 5    10010010  0.000351  0.002793
# 6     1000100  0.000353  0.002806
# 7       10010  0.000366  0.002897
# 8      111000  0.000378  0.002977
# 9     1000001  0.000384  0.003017
# 10  100000100  0.000387  0.003040
# 11   11111110  0.000390  0.003062
# 12  110111011  0.000390  0.003064
# 13   11011000  0.000392  0.003077
# 14  110110000  0.000395  0.003094
# 15  111001111  0.000411  0.003207
# 16      11011  0.000417  0.003248
# 17  111100111  0.000417  0.003248
# 18  101101101  0.000419  0.003260
# 19     110110  0.000421  0.003273
# 20  101000000  0.000422  0.003280
# 21  110111110  0.000437  0.003382
# 22   11111011  0.000439  0.003397
# 23        101  0.000457  0.003517
# ...

# %%
fakep = np.zeros(len(data.df))

k = 0.5
for i in range(len(data.df)):
    fakep[i] = k
    k *= 0.5
    
fakedata = pd.DataFrame(fakep, columns=["p"])
fakedata = BPV.Data(fakedata)
fakedata.calculate_entropy()
fakedata.df
# Out:
#                p      plog1onp
# 0   5.000000e-01  3.465736e-01
# 1   2.500000e-01  3.465736e-01
# 2   1.250000e-01  2.599302e-01
# 3   6.250000e-02  1.732868e-01
# 4   3.125000e-02  1.083042e-01
# 5   1.562500e-02  6.498255e-02
# 6   7.812500e-03  3.790649e-02
# 7   3.906250e-03  2.166085e-02
# 8   1.953125e-03  1.218423e-02
# 9   9.765625e-04  6.769015e-03
# 10  4.882812e-04  3.722958e-03
# 11  2.441406e-04  2.030705e-03
# 12  1.220703e-04  1.099965e-03
# 13  6.103516e-05  5.922889e-04
# 14  3.051758e-05  3.172976e-04
# 15  1.525879e-05  1.692254e-04
# 16  7.629395e-06  8.990099e-05
# 17  3.814697e-06  4.759464e-05
# 18  1.907349e-06  2.511939e-05
# 19  9.536743e-07  1.322073e-05
# 20  4.768372e-07  6.940885e-06
# 21  2.384186e-07  3.635702e-06
# 22  1.192093e-07  1.900480e-06
# 23  5.960464e-08  9.915550e-07
# 24  2.980232e-08  5.164349e-07
# 25  1.490116e-08  2.685461e-07
# 26  7.450581e-09  1.394374e-07
# 27  3.725290e-09  7.230089e-08
# 28  1.862645e-09  3.744153e-08
# ...

# %%
W= 0.006
N=15
Hprbl_exact = BPV.BPV("decgraphH",fakedata,N,W,time_solver=True)
Hprbl_exact.solve()
Hprbl_exact.pprint_solution()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-668bff96b3e1> in <module>()
#       2 N=15
#       3 Hprbl_exact = BPV.BPV("decgraphH",fakedata,N,W,time_solver=True)
# ----> 4 Hprbl_exact.solve()
#       5 Hprbl_exact.pprint_solution()
#
# /home/renato/Documents/Universita_/magistrale/tesi/code/notebooks/BPV.py in solve(self)
#     306     def solve(self):
#     307         if self.time_solver == True:
# --> 308             self.solution_time = timeit.timeit(self.solver,number=1)
#     309         else:
#     310             self.solver()
#
# /opt/anaconda/lib/python3.4/timeit.py in timeit(stmt, setup, timer, number)
#     217            number=default_number):
#     218     """Convenience function to create Timer object and call timeit method."""
# --> 219     return Timer(stmt, setup, timer).timeit(number)
#     220
# ...
